# %% [markdown]
# # Hypothesis Testing, Null Hypothesis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In the above fig we can see that meanHeight of class1 is < meanHeight of class2 so by this can we justify class2 students are taller than class1?<br>

# %% [markdown]
# ## 3 Steps process

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# here if we assume H0 as true and Finds if it is true the H0 is correct else H1 is correct, Its Proof By Contradiction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Check videos for Clear explanation/ check next notebooks
