# %% [markdown]
# # Confidence Interval

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # CI for Mean of R.V

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Case 1: where std deviation is given

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# By appling all the values in the above Interval we will get the Interval as below

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Case 2 if std dev is not given

# %% [markdown]
# Use T-distribution check video

# %% [markdown]
# ![image.png](attachment:image.png)
