# %% [markdown]
# # Correlation
#
# There are Three Ways To find Relation/co-relation between Rand Vars/Features:<br>
# 1) CoVariance<br>
# 2) Pearson Correlation Coeff<br>
# 3) Spearman Rank Corr Coeff.

# %% [markdown]
# ## Covariance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# DrawBack:<br>
# Example: cov(heightinCM,WeightinKgs) != cov(heightinFT,WeightInLBS)...
#
# This can be overcomed in Pearson Corr Coeff Methodology

# %% [markdown]
# # Pearson Correlation Coefficient
#  -1 <= p <= 1<br>
#  Its used for linear relationship

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# if p=0 then there is no relation between features.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Observation: From the Above diagram we can see that as p value decreases from 1 - 0 the std deviation is getting increased i.e more std deviation weak is the relation between the features

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Drawback:<br>
# Observation: In the above fig all the plots are non-linear, Through this PCC its hard to find the corelation when plot is non-linear.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The above is the formula for PCC

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Drawback:<br>
# In the Above graoh Its non Linear Curve But its Monotonically Increasing(i.e x inc y is also inc) but PCC is not 1 its 0.88 This is draw back of PCC it can be overcomed in Spearman Rank Correlation Coeff

# %% [markdown]
# # Spearman Rank Correlation Coeff

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here we calculate PCC for ranks of x,y

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Observation:<br>
# As Spearman uses rank's the outliers are handled perfectly than PCC

# %% [markdown]
# # Summary

# %% [markdown]
# CoVariance -> The variance may be too high or too low as deviation is not considered.<br>
#
# Pcc -> Here deviation is considered but drawback is It perfectly works for Linear Distributions.
#
# Spearmans Rank Corr Coeff -> Is the best method where It Calculates PCC based on the ranks of X,Y and Outliers are handled perfectly as its based on the rank.
