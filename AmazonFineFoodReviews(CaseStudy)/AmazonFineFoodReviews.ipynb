# %% [markdown]
# # Amazon Fine Food Reviews
#
# ## Sentiment Analysis

# %% [markdown]
# https://www.kaggle.com/snap/amazon-fine-food-reviews

# %% [markdown]
# ## Context
# This dataset consists of reviews of fine foods from amazon. The data span a period of more than 10 years, including all ~500,000 reviews up to October 2012. Reviews include product and user information, ratings, and a plain text review. It also includes reviews from all other Amazon categories.

# %% [markdown]
# Data includes:
# - Reviews from Oct 1999 - Oct 2012
# - 568,454 reviews
# - 256,059 users
# - 74,258 products
# - 260 users with > 50 reviews

# %% [markdown]
# Attribute Info:
# - id : reviewer id
# - Product id : unique id of the prod
# - UserId : unique id of user
# - ProfileName : Name of the user
# - HelpfulnessNumerator : no.of users who found the review helpful
# - HelpfulnessDenominator : no.of users who doesn't found the  review helpful.
# - Score : rating from 1-5
# - Time : timestamp for th review
# - Summary : Brief summary of the review
# - Text : Text of the review
#
# #### We Will eliminate some of the feautrs such as id and score.
#
# ### Objective:
# Given a review, we determine whether its a positive(rating 4,5) or negative(rating 1,2)

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# We are loading the data from the sqlite file.<br>
#
# We are ignoring the reviews with rating 3 as they are neither positive nor negative.

# %%
# %matplotlib inline

import sqlite3
import pandas as pd #for data frames
import numpy as np #numpy array operations
import nltk #natural lang processing, for processing text
import string
import matplotlib.pyplot as plt
import seaborn as sns #for plotting
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import roc_curve, auc
from nltk.stem.porter import PorterStemmer

# %%
# using sqlite table to read data

con = sqlite3.connect("database.sqlite")

# %%
# getting the reviews where rating is not equal to 3

filtered_data = pd.read_sql_query("""select * from Reviews where
score != 3
""",con)

# %%
filtered_data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
filtered_data.shape
# Out:
# (525814, 10)

# %% [markdown]
# ### Replacing scores with positive or negative

# %%
#Give review with score>3 as positive review and Score<3 as negative review

def partition(x):
    if x<3:
        return "negative"
    return "positive"


actualScore = filtered_data['Score']
positiveNegative = actualScore.map(partition)
filtered_data['Score'] = positiveNegative

# %%
filtered_data.shape
# Out:
# (525814, 10)

# %%
filtered_data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator     Score        Time  \
# 0                     1                       1  positive  1303862400
# 1                     0                       0  negative  1346976000
# 2                     1                       1  positive  1219017600
# 3                     3                       3  negative  1307923200
# 4                     0                       0  positive  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ## Data Cleaning: Deduplication

# %% [markdown]
# Its done to get the unbiased results

# %%
display = pd.read_sql_query("""
select * from Reviews where score !=3 and UserId="AR5J8UI46CURR" 
order by ProductID
""",con)

display
# Out:
#        Id   ProductId         UserId      ProfileName  HelpfulnessNumerator  \
# 0   78445  B000HDL1RQ  AR5J8UI46CURR  Geetha Krishnan                     2
# 1  138317  B000HDOPYC  AR5J8UI46CURR  Geetha Krishnan                     2
# 2  138277  B000HDOPYM  AR5J8UI46CURR  Geetha Krishnan                     2
# 3   73791  B000HDOPZG  AR5J8UI46CURR  Geetha Krishnan                     2
# 4  155049  B000PAQ75C  AR5J8UI46CURR  Geetha Krishnan                     2
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       2      5  1199577600
# 1                       2      5  1199577600
# 2                       2      5  1199577600
# 3                       2      5  1199577600
# 4                       2      5  1199577600
#
#                              Summary  \
# 0  LOACKER QUADRATINI VANILLA WAFERS
# 1  LOACKER QUADRATINI VANILLA WAFERS
# 2  LOACKER QUADRATINI VANILLA WAFERS
# 3  LOACKER QUADRATINI VANILLA WAFERS
# 4  LOACKER QUADRATINI VANILLA WAFERS
#
#                                                 Text
# 0  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 1  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 2  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 3  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 4  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...

# %% [markdown]
# In the Above table we can see that User named Geetha Krishnan has reviewd a product and we can see that there are 5 products with same text, summary, Timestamp, How one can rate 5 products at the same time i.e Amazon is sharing the reviews if there are almost similar/ same products. This is duplication so we will remove 4 and retain 1.

# %% [markdown]
# We Can check the amaozon product with Product id with below link<br>
#
# https://www.amazon.com/dp/[PRODUCT ID]  - > https://www.amazon.com/dp/B000HDL1RQ

# %%
# sorting data according to prodid

sorted_data = filtered_data.sort_values("ProductId",axis=0,ascending=True)

# %%
#Droping dup entries
# when "UserId","ProfileName","Time","Text" are same then remove dup

#1st param subset-> if these cols are same for every prod then its dup
# 2nd param Keep -> first /last/false -> keep first occ or last occ or rmv all
#3rd param -> inplace true-> return a dup copy false-> drop the entry
# returns the data frame
final = sorted_data.drop_duplicates(subset={"UserId","ProfileName","Time","Text"},keep="first",inplace=False)
final.shape
# Out:
# (364173, 10)

# %% [markdown]
# Observation: there were 5 lakh data points before cleaning now 364173 data points

# %%
final.head()
# Out:
#             Id   ProductId          UserId                  ProfileName  \
# 138706  150524  0006641040   ACITT7DI6IDDL              shari zychinski
# 138688  150506  0006641040  A2IW4PEEKO2R0U                        Tracy
# 138689  150507  0006641040  A1S4A3IQ2MU7V4        sally sue "sally sue"
# 138690  150508  0006641040     AZGXZ2UUK6X  Catherine Hallberg "(Kate)"
# 138691  150509  0006641040  A3CMRKGE0P909G                       Teresa
#
#         HelpfulnessNumerator  HelpfulnessDenominator     Score        Time  \
# 138706                     0                       0  positive   939340800
# 138688                     1                       1  positive  1194739200
# 138689                     1                       1  positive  1191456000
# 138690                     1                       1  positive  1076025600
# 138691                     3                       4  positive  1018396800
#
#                                            Summary  \
# 138706                   EVERY book is educational
# 138688  Love the book, miss the hard cover version
# 138689               chicken soup with rice months
# 138690      a good swingy rhythm for reading aloud
# 138691             A great way to learn the months
#
#                                                      Text
# 138706  this witty little book makes my son laugh at l...
# 138688  I grew up reading these Sendak books, and watc...
# 138689  This is a fun way for children to learn their ...
# 138690  This is a great little book to read aloud- it ...
# 138691  This is a book of poetry about the months of t...

# %% [markdown]
# ### Cleaning data with common sence Scenarios
#
# always HelpfulnessNumerator <= HelpfullnessDenominator i.e HelpfulnessNumerator is ntg but ThumbsUp clicked for the review and HelpfullnessDenom is ntg but both ThumbsUp and ThumbsDown given to the Review.
#
# <br>
# So lets check if there are any data points deviating this condition so that we can remove them.

# %%
final = final[final["HelpfulnessNumerator"] <= final["HelpfulnessDenominator"]]
final.shape
# Out:
# (364171, 10)

# %% [markdown]
# Observation: 2 records were removed as they were wrong etries

# %%
### Checking No.of positive and Negative Reviews

final['Score'].value_counts()
# Out:
# positive    307061
# negative     57110
# Name: Score, dtype: int64

# %% [markdown]
# Observation: There are More no.of positive reviews than negative reviews

# %% [markdown]
# ## Text To d-dim Vector

# %% [markdown]
# #### Why to convert?
#
# If we convert Text to vector Then we can Use Linear Algebra Techniques To Classify and Visualize the data.

# %% [markdown]
# <img src= "images/reviews1.png"/>

# %% [markdown]
# By using Linear Algebra we can classify the points like this i.e we will find a plane/line such that it divides the positive reviews to one side and negative reviews to other side

# %% [markdown]
# # Bag of Words(BOW)
#
# Bag of words is a technique Where the Text is converted to vectors.<br>
# Its Most Widely used for Classification/Filtering problems.<br>
# Mostly the Frequency of words is mentioned in the vectors through which we can find the similarity between the vectors and classify.<br>
#
# Its most widely used IR technique.

# %% [markdown]
# <img src="images/reviews2.png"/>

# %% [markdown]
# <img src="images/reviews3.png"/>

# %% [markdown]
# ## Explanation of Terms in BOW
#
# In the image 1 r1 r2... reviews are called Documents.
#
# Collection of All the documents is called "Corpus"

# %% [markdown]
# in Bow first we convert the Text to d-dim vector as shown above.
#
# Step1: Dictionary(not py term its eng term) i.e BOW Vector : set of all the unique words in the documents is created
#
# Step2: All the Documents/reviews are converted to d-dim vectors as shown in the image.
#
# Note: Each word in the Document is one dimension

# %% [markdown]
# <img src = "images/reviews4.png"/>

# %% [markdown]
# In this The words like This Is  and are not useful these words are called STOP WORDS, we will remove these words by Text Preprocessing

# %% [markdown]
# # Text PreProcessing

# %% [markdown]
# - Stemming : Example: Taste, Tasteful, Tastes these are converted to Stem word Taste.
#
# - Stop words Rmemoval
#
# - Tokenization : the process of breaking the sentance into words
#
# - Lemmatization : Breaking the sentance into words meaningfully for example 'New York' its one word not 2 words.

# %% [markdown]
# Note: BOW doesnt consider Semantics of the word i.e If there are words like "Beautiful", "Awesome" BOW treats them as different words.

# %% [markdown]
# # TF-IDF

# %% [markdown]
# Term Frequency - Inverse Doc Frequency

# %% [markdown]
# Term Frequency = (occ of word wi in the document/no of words in the doc)
#
# Inverse Doc Frequency = log(Number of Words in the Doc Corpus i.e all docs / occ of word in that doc)
#
#
# tfIdf = tf * idf <br>
#
# Term Freq increases if the occ of the word is more.
#
# Inverse Doc Freq increases if the word is rare in the Doc corpous.

# %% [markdown]
# # Word2Vec

# %% [markdown]
# In Word to vec we will consider a word and its converted to Vector while in Bag of words every sentence is converted to vector

# %% [markdown]
# https://www.tensorflow.org/tutorials/word2vec

# %% [markdown]
# It even knows the relations like men-women etc

# %% [markdown]
# # Text Preprocessing Code

# %% [markdown]
# - Remove html tags in our reviews
# - Remove Punctuations
# - remove alphanumeric
# - remove single letter words
# - convert to lower case
# - stemming

# %%
# Regular exp practice

import re

import string
from nltk.corpus import stopwords

from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

stop = set(stopwords.words('english')) #set of stop words

sno =nltk.stem.SnowballStemmer('english') 

def cleanhtml(sentence):
    cleanr = re.compile('<.*?>') #removes all th html tags
    cleantext = re.sub(cleanr,' ',sentence)
    return cleantext

def cleanpunc(sentence):
    cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    return cleaned
print(stop)
print("-----------------------------------------------------------------")
print(sno.stem('tasteful'))
print(sno.stem('tasty'))
print(sno.stem('test'))
print(sno.stem('testing'))
cleanpunc("Father's").split()
# Out:
# {'by', "didn't", "should've", 'y', 'yourself', 'do', 'more', 'haven', 'each', 'ourselves', 'have', 'at', 'shouldn', "that'll", 'is', 'after', 'under', 'and', 'few', 'against', 'from', 'there', 'to', 'has', 'its', 'below', 've', 'why', 'we', 'up', "hasn't", "you'll", "needn't", 'having', 'out', 'are', 'him', 'd', 'it', "you're", 'won', 'was', 'because', "mustn't", "it's", 'couldn', 'didn', "couldn't", 'been', 'hers', 's', "mightn't", "she's", 'such', 'which', 'or', 'll', 'too', 'wouldn', 'my', 'who', "you'd", 'being', 'very', 'wasn', "isn't", 'that', 'during', "aren't", 'the', "shouldn't", 'what', 'of', 'further', 't', 'ma', 'you', 'into', 'his', 'before', "shan't", 'should', "you've", 'had', 'were', 'now', 'down', 'between', 'yourselves', 'in', 'through', 'be', 'this', 'so', 'all', 'ain', 'than', 'yours', 'm', 'then', 'whom', 'theirs', 'am', 'not', 'but', 'did', "doesn't", "wouldn't", 'themselves', 'until', 'doing', 'any', 'when', "don't", 'while', 'again', 'hasn', "won't", 'i', 'hadn', 'just', 'a', 'himself', 'can', 'will', 'once', "haven't", 'for', 'mightn', 'her', 'if', 'off', 'myself', 'own', 'them', 'does', 're', 'ours', 'your', 'nor', 'they', 'don', 'these', 'itself', 'with', 'he', 'our', 'she', 'some', 'o', 'needn', "hadn't", 'how', 'other', 'above', 'me', "wasn't", 'weren', 'isn', 'mustn', 'over', 'as', 'where', 'no', 'those', 'their', 'here', 'doesn', 'both', 'about', 'shan', 'same', "weren't", 'most', 'only', 'herself', 'on', 'aren', 'an'}
# -----------------------------------------------------------------
# tast
# tasti
# test
# test
# ['Fathers']

# %% [markdown]
# ## Dont run this code....Executed this already and stored in sqlite file

# %%
#Code for implementing step-by-step the checks mentioned in the pre-processing phase
# this code takes a while to run as it needs to run on 500k sentences.

'''
i=0
str1=' '
final_string=[]
all_positive_words=[] # store words from +ve reviews here
all_negative_words=[] # store words from -ve reviews here.
s=''
for sent in final['Text'].values:
    filtered_sentence=[]
    #print(sent);
    sent=cleanhtml(sent) # remove HTMl tags
    for w in sent.split():
        for cleaned_words in cleanpunc(w).split():
            if((cleaned_words.isalpha()) & (len(cleaned_words)>2)):    
                if(cleaned_words.lower() not in stop):
                    s=(sno.stem(cleaned_words.lower())).encode('utf8')
                    filtered_sentence.append(s)
                    if (final['Score'].values)[i] == 'positive': 
                        all_positive_words.append(s) #list of all words used to describe positive reviews
                    if(final['Score'].values)[i] == 'negative':
                        all_negative_words.append(s) #list of all words used to describe negative reviews reviews
                else:
                    continue
            else:
                continue 
    #print("Filtered sent:",filtered_sentence)
    str1 = b" ".join(filtered_sentence) #final string of cleaned words
    #print("***********************************************************************")
    
    final_string.append(str1)
    i+=1
    

'''
# Out:
# '\ni=0\nstr1=\' \'\nfinal_string=[]\nall_positive_words=[] # store words from +ve reviews here\nall_negative_words=[] # store words from -ve reviews here.\ns=\'\'\nfor sent in final[\'Text\'].values:\n    filtered_sentence=[]\n    #print(sent);\n    sent=cleanhtml(sent) # remove HTMl tags\n    for w in sent.split():\n        for cleaned_words in cleanpunc(w).split():\n            if((cleaned_words.isalpha()) & (len(cleaned_words)>2)):    \n                if(cleaned_words.lower() not in stop):\n                    s=(sno.stem(cleaned_words.lower())).encode(\'utf8\')\n                    filtered_sentence.append(s)\n                    if (final[\'Score\'].values)[i] == \'positive\': \n                        all_positive_words.append(s) #list of all words used to describe positive reviews\n                    if(final[\'Score\'].values)[i] == \'negative\':\n                        all_negative_words.append(s) #list of all words used to describe negative reviews reviews\n                else:\n                    continue\n            else:\n                continue \n    #print("Filtered sent:",filtered_sentence)\n    str1 = b" ".join(filtered_sentence) #final string of cleaned words\n    #print("***********************************************************************")\n    \n    final_string.append(str1)\n    i+=1\n    \n\n'

# %%
# adding a column of CleanedText which displays the data 
# after pre-processing of the review 
'''
final['CleanedText']=final_string
'''
# Out:
# "\nfinal['CleanedText']=final_string\n"

# %%
'''
final.head(3) #below the processed review can be seen in the CleanedText Column 


# store final table into an SQlLite table for future.
conn = sqlite3.connect('final.sqlite')
c=conn.cursor()
conn.text_factory = str
final.to_sql('Reviews', conn, flavor=None, schema=None, if_exists='replace', index=True, index_label=None, chunksize=None, dtype=None)
'''
# Out:
# "\nfinal.head(3) #below the processed review can be seen in the CleanedText Column \n\n\n# store final table into an SQlLite table for future.\nconn = sqlite3.connect('final.sqlite')\nc=conn.cursor()\nconn.text_factory = str\nfinal.to_sql('Reviews', conn, flavor=None, schema=None, if_exists='replace', index=True, index_label=None, chunksize=None, dtype=None)\n"

# %%
# creating pickle file for this 50k data points as 
# this took huge time to compute


import pickle
'''
pickle_out = open("cleanedData.pickle","wb")
pickle.dump(final,pickle_out)
pickle.dump(all_positive_words,pickle_out)
pickle.dump(all_negative_words,pickle_out)
pickle_out.close()
'''
# Out:
# '\npickle_out = open("cleanedData.pickle","wb")\npickle.dump(final,pickle_out)\npickle.dump(all_positive_words,pickle_out)\npickle.dump(all_negative_words,pickle_out)\npickle_out.close()\n'

# %%
pickle_in=open("cleanedData.pickle","rb")
pik = pickle.load(pickle_in)
pik.head(2)
all_positive_words = pickle.load(pickle_in)
all_negative_words = pickle.load(pickle_in)
all_positive_words
# Out:
# [b'witti',
#  b'littl',
#  b'book',
#  b'make',
#  b'son',
#  b'laugh',
#  b'loud',
#  b'recit',
#  b'car',
#  b'drive',
#  b'along',
#  b'alway',
#  b'sing',
#  b'refrain',
#  b'hes',
#  b'learn',
#  b'whale',
#  b'india',
#  b'droop',
#  b'love',
#  b'new',
#  b'word',
#  b'book',
#  b'introduc',
#  b'silli',
#  b'classic',
#  b'book',
#  b'will',
#  b'bet',
#  b'son',
#  b'still',
#  b'abl',
#  b'recit',
#  b'memori',
#  b'colleg',
#  b'grew',
#  b'read',
#  b'sendak',
#  b'book',
#  b'watch',
#  b'realli',
#  b'rosi',
#  b'movi',
#  b'incorpor',
#  b'love',
#  b'son',
#  b'love',
#  b'howev',
#  b'miss',
#  b'hard',
#  b'cover',
#  b'version',
#  b'paperback',
#  b'seem',
#  b'kind',
#  b'flimsi',
#  b'take',
#  b'two',
#  b'hand',
#  b'keep',
#  b'page',
#  b'open',
#  b'fun',
#  b'way',
#  b'children',
#  b'learn',
#  b'month',
#  b'year',
#  b'learn',
#  b'poem',
#  b'throughout',
#  b'school',
#  b'year',
#  b'like',
#  b'handmot',
#  b'invent',
#  b'poem',
#  b'great',
#  b'littl',
#  b'book',
#  b'read',
#  b'nice',
#  b'rhythm',
#  b'well',
#  b'good',
#  b'repetit',
#  b'littl',
#  b'one',
#  b'like',
#  b'line',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'child',
#  b'get',
#  b'month',
#  b'year',
#  b'wonder',
#  b'place',
#  b'like',
#  b'bombay',
#  b'nile',
#  b'eat',
#  b'well',
#  b'know',
#  b'get',
#  b'eat',
#  b'kid',
#  b'mauric',
#  b'sendak',
#  b'version',
#  b'ice',
#  b'skate',
#  b'treat',
#  b'rose',
#  b'head',
#  b'long',
#  b'time',
#  b'wont',
#  b'even',
#  b'know',
#  b'came',
#  b'surpris',
#  b'came',
#  b'littl',
#  b'witti',
#  b'book',
#  b'book',
#  b'poetri',
#  b'month',
#  b'year',
#  b'goe',
#  b'month',
#  b'cute',
#  b'littl',
#  b'poem',
#  b'along',
#  b'love',
#  b'book',
#  b'realli',
#  b'fun',
#  b'way',
#  b'learn',
#  b'month',
#  b'poem',
#  b'creativ',
#  b'author',
#  b'purpos',
#  b'write',
#  b'book',
#  b'give',
#  b'children',
#  b'fun',
#  b'way',
#  b'learn',
#  b'month',
#  b'children',
#  b'also',
#  b'learn',
#  b'thing',
#  b'poetri',
#  b'rhythm',
#  b'read',
#  b'book',
#  b'charm',
#  b'rhyme',
#  b'book',
#  b'describ',
#  b'circumst',
#  b'eat',
#  b'dont',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'sound',
#  b'like',
#  b'kind',
#  b'thing',
#  b'kid',
#  b'would',
#  b'make',
#  b'theyr',
#  b'recess',
#  b'sing',
#  b'drive',
#  b'teacher',
#  b'crazi',
#  b'cute',
#  b'catchi',
#  b'sound',
#  b'realli',
#  b'childlik',
#  b'skill',
#  b'written',
#  b'set',
#  b'asid',
#  b'least',
#  b'hour',
#  b'day',
#  b'read',
#  b'son',
#  b'point',
#  b'consid',
#  b'connoisseur',
#  b'children',
#  b'book',
#  b'one',
#  b'best',
#  b'santa',
#  b'claus',
#  b'put',
#  b'tree',
#  b'sinc',
#  b'weve',
#  b'read',
#  b'perpetu',
#  b'love',
#  b'first',
#  b'book',
#  b'taught',
#  b'month',
#  b'year',
#  b'second',
#  b'pleasur',
#  b'read',
#  b'well',
#  b'suit',
#  b'old',
#  b'children',
#  b'book',
#  b'worth',
#  b'own',
#  b'borrow',
#  b'librari',
#  b'book',
#  b'howev',
#  b'deserv',
#  b'perman',
#  b'spot',
#  b'shelf',
#  b'sendak',
#  b'best',
#  b'rememb',
#  b'book',
#  b'childhood',
#  b'got',
#  b'kid',
#  b'good',
#  b'rememb',
#  b'kid',
#  b'love',
#  b'older',
#  b'daughter',
#  b'read',
#  b'sister',
#  b'good',
#  b'rhyme',
#  b'nice',
#  b'pictur',
#  b'great',
#  b'book',
#  b'ador',
#  b'illustr',
#  b'true',
#  b'classic',
#  b'kid',
#  b'love',
#  b'poem',
#  b'music',
#  b'goe',
#  b'find',
#  b'think',
#  b'sung',
#  b'carol',
#  b'king',
#  b'book',
#  b'famili',
#  b'favorit',
#  b'read',
#  b'children',
#  b'small',
#  b'order',
#  b'new',
#  b'famili',
#  b'enjoy',
#  b'get',
#  b'movi',
#  b'sound',
#  b'track',
#  b'sing',
#  b'along',
#  b'carol',
#  b'king',
#  b'great',
#  b'stuff',
#  b'whole',
#  b'extend',
#  b'famili',
#  b'know',
#  b'song',
#  b'heart',
#  b'qualiti',
#  b'kid',
#  b'storytel',
#  b'music',
#  b'author',
#  b'wrote',
#  b'wild',
#  b'thing',
#  b'carol',
#  b'king',
#  b'wrote',
#  b'great',
#  b'song',
#  b'match',
#  b'lyric',
#  b'illustr',
#  b'fabul',
#  b'wish',
#  b'could',
#  b'buy',
#  b'hardbound',
#  b'larger',
#  b'tini',
#  b'book',
#  b'easili',
#  b'misplac',
#  b'carri',
#  b'everywher',
#  b'great',
#  b'book',
#  b'perfect',
#  b'condit',
#  b'arriv',
#  b'short',
#  b'amount',
#  b'time',
#  b'long',
#  b'expect',
#  b'deliveri',
#  b'date',
#  b'ive',
#  b'alway',
#  b'love',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'late',
#  b'ethel',
#  b'alway',
#  b'made',
#  b'homemad',
#  b'chicken',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'book',
#  b'take',
#  b'back',
#  b'day',
#  b'mother',
#  b'father',
#  b'sister',
#  b'went',
#  b'ethel',
#  b'hous',
#  b'late',
#  b'isador',
#  b'would',
#  b'cook',
#  b'chicken',
#  b'ethel',
#  b'blind',
#  b'remind',
#  b'time',
#  b'togeth',
#  b'famili',
#  b'bring',
#  b'back',
#  b'happi',
#  b'memori',
#  b'love',
#  b'share',
#  b'bowl',
#  b'hot',
#  b'soup',
#  b'book',
#  b'purchas',
#  b'birthday',
#  b'gift',
#  b'year',
#  b'old',
#  b'boy',
#  b'squeal',
#  b'delight',
#  b'hug',
#  b'told',
#  b'keep',
#  b'return',
#  b'librari',
#  b'year',
#  b'old',
#  b'daughter',
#  b'brought',
#  b'book',
#  b'home',
#  b'school',
#  b'librari',
#  b'littl',
#  b'easi',
#  b'read',
#  b'skill',
#  b'love',
#  b'anyway',
#  b'year',
#  b'old',
#  b'daughter',
#  b'start',
#  b'read',
#  b'cant',
#  b'get',
#  b'return',
#  b'school',
#  b'book',
#  b'small',
#  b'better',
#  b'littl',
#  b'hand',
#  b'great',
#  b'book',
#  b'age',
#  b'pictur',
#  b'cute',
#  b'well',
#  b'write',
#  b'rhyme',
#  b'make',
#  b'easi',
#  b'get',
#  b'know',
#  b'month',
#  b'recommend',
#  b'book',
#  b'everi',
#  b'parent',
#  b'book',
#  b'contain',
#  b'collect',
#  b'twelv',
#  b'short',
#  b'statement',
#  b'end',
#  b'phrase',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'one',
#  b'base',
#  b'month',
#  b'year',
#  b'element',
#  b'nonsens',
#  b'vers',
#  b'reason',
#  b'children',
#  b'find',
#  b'entertain',
#  b'generat',
#  b'giggl',
#  b'young',
#  b'boy',
#  b'describ',
#  b'use',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'month',
#  b'year',
#  b'sendak',
#  b'creativ',
#  b'repetiti',
#  b'rhythmic',
#  b'word',
#  b'children',
#  b'enjoy',
#  b'learn',
#  b'read',
#  b'stori',
#  b'boy',
#  b'love',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'sendak',
#  b'catchi',
#  b'stori',
#  b'children',
#  b'also',
#  b'learn',
#  b'month',
#  b'year',
#  b'well',
#  b'season',
#  b'month',
#  b'learn',
#  b'identifi',
#  b'snowmen',
#  b'strong',
#  b'wind',
#  b'bird',
#  b'flower',
#  b'swim',
#  b'hot',
#  b'temperatur',
#  b'final',
#  b'differ',
#  b'holiday',
#  b'throughout',
#  b'year',
#  b'halloween',
#  b'octob',
#  b'christma',
#  b'decemb',
#  b'sendak',
#  b'simpl',
#  b'three',
#  b'color',
#  b'draw',
#  b'perfect',
#  b'addit',
#  b'educ',
#  b'entertain',
#  b'stori',
#  b'great',
#  b'activ',
#  b'book',
#  b'children',
#  b'draw',
#  b'illustr',
#  b'month',
#  b'year',
#  b'afterward',
#  b'bind',
#  b'page',
#  b'togeth',
#  b'children',
#  b'creat',
#  b'book',
#  b'daughter',
#  b'love',
#  b'realli',
#  b'rosi',
#  b'book',
#  b'introduc',
#  b'realli',
#  b'rosi',
#  b'perform',
#  b'carol',
#  b'king',
#  b'also',
#  b'avail',
#  b'amazon',
#  b'birthday',
#  b'year',
#  b'later',
#  b'know',
#  b'song',
#  b'far',
#  b'book',
#  b'one',
#  b'johnni',
#  b'allig',
#  b'around',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'book',
#  b'well',
#  b'written',
#  b'clever',
#  b'art',
#  b'work',
#  b'mauric',
#  b'sendak',
#  b'plus',
#  b'realli',
#  b'cheap',
#  b'high',
#  b'recommend',
#  b'june',
#  b'saw',
#  b'charm',
#  b'group',
#  b'rose',
#  b'begin',
#  b'droop',
#  b'pep',
#  b'chicken',
#  b'soup',
#  b'sprinkl',
#  b'sprinkl',
#  b'twice',
#  b'sprinkl',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'great',
#  b'book',
#  b'teach',
#  b'children',
#  b'month',
#  b'year',
#  b'repetit',
#  b'phrase',
#  b'funni',
#  b'littl',
#  b'stori',
#  b'accompani',
#  b'pictur',
#  b'make',
#  b'ideal',
#  b'bedtim',
#  b'read',
#  b'isnt',
#  b'near',
#  b'good',
#  b'sendak',
#  b'book',
#  b'like',
#  b'wild',
#  b'thing',
#  b'boy',
#  b'didnt',
#  b'care',
#  b'still',
#  b'carri',
#  b'uniqu',
#  b'brand',
#  b'charm',
#  b'classic',
#  b'children',
#  b'book',
#  b'cant',
#  b'wrong',
#  b'read',
#  b'kid',
#  b'order',
#  b'later',
#  b'cant',
#  b'beat',
#  b'entertain',
#  b'rhyme',
#  b'catchi',
#  b'illustr',
#  b'imagin',
#  b'fit',
#  b'right',
#  b'howev',
#  b'paperback',
#  b'somewhat',
#  b'small',
#  b'flimsi',
#  b'opt',
#  b'bigger',
#  b'edit',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'mauric',
#  b'sendak',
#  b'josh',
#  b'grossman',
#  b'colonel',
#  b'facp',
#  b'rural',
#  b'physician',
#  b'author',
#  b'step',
#  b'would',
#  b'believ',
#  b'memor',
#  b'book',
#  b'would',
#  b'believ',
#  b'recit',
#  b'month',
#  b'order',
#  b'would',
#  b'believ',
#  b'read',
#  b'copi',
#  b'tatter',
#  b'read',
#  b'children',
#  b'profession',
#  b'adult',
#  b'would',
#  b'believ',
#  b'grandchildren',
#  b'read',
#  b'copi',
#  b'tatter',
#  b'confid',
#  b'generat',
#  b'children',
#  b'enjoy',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'bravo',
#  b'thank',
#  b'respect',
#  b'submit',
#  b'wonder',
#  b'littl',
#  b'book',
#  b'love',
#  b'year',
#  b'ago',
#  b'twin',
#  b'love',
#  b'enjoy',
#  b'help',
#  b'finish',
#  b'month',
#  b'sing',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'cute',
#  b'draw',
#  b'add',
#  b'fun',
#  b'warn',
#  b'one',
#  b'toto',
#  b'children',
#  b'love',
#  b'book',
#  b'first',
#  b'grader',
#  b'got',
#  b'christma',
#  b'love',
#  b'read',
#  b'rhyme',
#  b'proud',
#  b'month',
#  b'teacher',
#  b'work',
#  b'month',
#  b'book',
#  b'read',
#  b'independ',
#  b'yet',
#  b'girl',
#  b'especi',
#  b'enjoy',
#  b'read',
#  b'month',
#  b'born',
#  b'sing',
#  b'go',
#  b'go',
#  b'twice',
#  b'go',
#  b'chicken',
#  b'soup',
#  b'rice',
#  b'book',
#  b'classic',
#  b'rememb',
#  b'childhood',
#  b'high',
#  b'recommend',
#  b'wish',
#  b'book',
#  b'larger',
#  b'size',
#  b'tend',
#  b'get',
#  b'lost',
#  b'bookshelf',
#  b'among',
#  b'regular',
#  b'size',
#  b'book',
#  b'one',
#  b'earliest',
#  b'memori',
#  b'book',
#  b'mother',
#  b'read',
#  b'constant',
#  b'read',
#  b'one',
#  b'quot',
#  b'fact',
#  b'typic',
#  b'sort',
#  b'soup',
#  b'would',
#  b'beg',
#  b'groceri',
#  b'book',
#  b'sinc',
#  b'use',
#  b'book',
#  b'everi',
#  b'class',
#  b'teach',
#  b'situat',
#  b'never',
#  b'met',
#  b'child',
#  b'love',
#  b'ask',
#  b'read',
#  b'sure',
#  b'beat',
#  b'stupid',
#  b'song',
#  b'sing',
#  b'preschool',
#  b'month',
#  b'year',
#  b'even',
#  b'mauric',
#  b'sendak',
#  b'fan',
#  b'enjoy',
#  b'one',
#  b'origin',
#  b'poetic',
#  b'grand',
#  b'daughter',
#  b'favorit',
#  b'book',
#  b'read',
#  b'love',
#  b'rhythm',
#  b'cute',
#  b'stori',
#  b'actual',
#  b'enjoy',
#  b'read',
#  b'copi',
#  b'smaller',
#  b'expect',
#  b'most',
#  b'didnt',
#  b'pay',
#  b'attent',
#  b'list',
#  b'dimens',
#  b'book',
#  b'mauric',
#  b'sendak',
#  b'wonder',
#  b'littl',
#  b'book',
#  b'month',
#  b'rhyme',
#  b'absolut',
#  b'silli',
#  b'much',
#  b'fun',
#  b'read',
#  b'rememb',
#  b'fond',
#  b'child',
#  b'want',
#  b'make',
#  b'sure',
#  b'littl',
#  b'one',
#  b'book',
#  b'shelf',
#  b'cute',
#  b'way',
#  b'teach',
#  b'month',
#  b'year',
#  b'mention',
#  b'celebr',
#  b'person',
#  b'love',
#  b'soup',
#  b'beauti',
#  b'illustr',
#  b'way',
#  b'sendak',
#  b'rememb',
#  b'see',
#  b'show',
#  b'air',
#  b'televis',
#  b'year',
#  b'ago',
#  b'child',
#  b'sister',
#  b'later',
#  b'bought',
#  b'day',
#  b'thirti',
#  b'someth',
#  b'use',
#  b'seri',
#  b'book',
#  b'song',
#  b'student',
#  b'teach',
#  b'preschool',
#  b'turn',
#  b'whole',
#  b'school',
#  b'purchas',
#  b'along',
#  b'book',
#  b'children',
#  b'tradit',
#  b'live',
#  b'day',
#  b'person',
#  b'say',
#  b'chicken',
#  b'soup',
#  b'theyr',
#  b'probabl',
#  b'go',
#  b'follow',
#  b'word',
#  b'soul',
#  b'mayb',
#  b'teenag',
#  b'soul',
#  b'didnt',
#  b'use',
#  b'way',
#  b'rememb',
#  b'time',
#  b'person',
#  b'said',
#  b'chicken',
#  b'soup',
#  b'word',
#  b'follow',
#  b'enthusiast',
#  b'rice',
#  b'power',
#  b'mauric',
#  b'sendak',
#  b'catchi',
#  b'children',
#  b'book',
#  b'pleas',
#  b'report',
#  b'care',
#  b'read',
#  b'book',
#  b'today',
#  b'find',
#  b'hasnt',
#  b'dimish',
#  b'jot',
#  b'term',
#  b'frolicksom',
#  b'fun',
#  b'book',
#  b'led',
#  b'whirlwind',
#  b'chicken',
#  b'soup',
#  b'year',
#  b'host',
#  b'boy',
#  b'bear',
#  b'littl',
#  b'resembl',
#  b'sendak',
#  b'great',
#  b'rhyme',
#  b'tale',
#  b'pierr',
#  b'look',
#  b'demeanor',
#  b'catchi',
#  b'flounci',
#  b'bounci',
#  b'combo',
#  b'soup',
#  b'peopl',
#  b'love',
#  b'ostens',
#  b'book',
#  b'meant',
#  b'teach',
#  b'children',
#  b'differ',
#  b'month',
#  ...]

# %% [markdown]
# # Bag of Words Code

# %% [markdown]
# Now we are taking every review and converting them to vectors

# %%
count_vect = CountVectorizer() #scikit-learn

final_counts = count_vect.fit_transform(final['Text'].values)

# %%
type(final_counts) #its a compressed sparse matrix i.e it only stores non zero vals in the format row,col ->val
# Out:
# scipy.sparse.csr.csr_matrix

# %%
final_counts.shape
# Out:
# (364171, 115281)

# %% [markdown]
# Observation: 364171 Reviews and 115281 unique words in the reviews

# %% [markdown]
# # Bi-Grams and N-grams

# %% [markdown]
# Now We have all positive and negative reviews in two lists, now lets get the frequency of most common positive reviews and most common negative reviews

# %%
freq_dist_positive = nltk.FreqDist(all_positive_words)
freq_dist_negative = nltk.FreqDist(all_negative_words)

print("Most Common Positive Words: ",freq_dist_positive.most_common(20))
print("Most Common Negative Words: ",freq_dist_negative.most_common(20))
# Out:
# Most Common Positive Words:  [(b'like', 139429), (b'tast', 129047), (b'good', 112766), (b'flavor', 109624), (b'love', 107357), (b'use', 103888), (b'great', 103870), (b'one', 96726), (b'product', 91033), (b'tri', 86791), (b'tea', 83888), (b'coffe', 78814), (b'make', 75107), (b'get', 72125), (b'food', 64802), (b'would', 55568), (b'time', 55264), (b'buy', 54198), (b'realli', 52715), (b'eat', 52004)]
# Most Common Negative Words:  [(b'tast', 34585), (b'like', 32330), (b'product', 28218), (b'one', 20569), (b'flavor', 19575), (b'would', 17972), (b'tri', 17753), (b'use', 15302), (b'good', 15041), (b'coffe', 14716), (b'get', 13786), (b'buy', 13752), (b'order', 12871), (b'food', 12754), (b'dont', 11877), (b'tea', 11665), (b'even', 11085), (b'box', 10844), (b'amazon', 10073), (b'make', 9840)]

# %%
# bigrams, trigrams, ngrams

# we should not remove stop word like 'not' by default 
# it will be removed so before removing we need to perform this

# (1,2) indicates unigrams and bigrams if its (1,3) -> uni,bi and trigrams

'''
count_vect = CountVectorizer(ngram_range=(1,2))
final_uni_bigrams_count = count_vect.fit_transform(final['Text'].values)
'''
# Out:
# "\ncount_vect = CountVectorizer(ngram_range=(1,2))\nfinal_uni_bigrams_count = count_vect.fit_transform(final['Text'].values)\n"

# %%
'''
pickle_out = open("n_grams.pickle","wb")
pickle.dump(final_uni_bigrams_count,pickle_out)
pickle_out.close()
'''
# Out:
# '\npickle_out = open("n_grams.pickle","wb")\npickle.dump(final_uni_bigrams_count,pickle_out)\npickle_out.close()\n'

# %%
pickle_in=open("n_grams.pickle","rb")
final_uni_bigrams_count = pickle.load(pickle_in)

# %%
final_uni_bigrams_count.get_shape()
# Out:
# (364171, 2910192)

# %% [markdown]
# Observation: here we have 29lakhs unique uni and bigrams In the case of bag of words we got 115281 unique words

# %% [markdown]
# # TF-IDF

# %%
tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))

final_tf_idf = tf_idf_vect.fit_transform(final['Text'].values)

# %%
final_tf_idf.get_shape()
# Out:
# (364171, 2910192)

# %%
final_tf_idf[1]
# Out:
# <1x2910192 sparse matrix of type '<class 'numpy.float64'>'
# 	with 84 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Observation: As it is a compressed sparse matrix we cant access the data with index.

# %%
# we can access the data like this
# getting all the unique words from the tf_idf_vect

features = tf_idf_vect.get_feature_names()

len(features)
# Out:
# 2910192

# %%
features[100000:100010]
tf_idf_vect
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %% [markdown]
# Above are the 10 words uni and bi grams

# %%
# To convert a row of sparse matrix to numpy array

print(final_tf_idf[100000,:].toarray()[0])
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %% [markdown]
# Observation: as its a sparse matrix most of the vals are 0

# %% [markdown]
# ### Function to retrieve top 25 features/words for a given review

# %%
def top_tfidf_feats(row,features,top_n=25):
    
    #here argsort will return the top 25 features indices
    topn_ids = np.argsort(row)[::-1][:top_n]
    top_feats = [(features[i],row[i]) for i in topn_ids]
    
    df = pd.DataFrame(top_feats)
    df.columns = ['features','tfidf']
    return df

top_tfidf = top_tfidf_feats(final_tf_idf[10,:].toarray()[0],features,25)

# %%
top_tfidf
# Out:
#              features     tfidf
# 0          with carol  0.194840
# 1            songs by  0.194840
# 2        quality kids  0.194840
# 3   kids storytelling  0.194840
# 4       heart quality  0.194840
# 5            or sound  0.194840
# 6    storytelling and  0.194840
# 7           king this  0.188815
# 8         these songs  0.188815
# 9         sound track  0.188815
# 10         carol king  0.184540
# 11         sing along  0.184540
# 12       storytelling  0.181225
# 13           and sing  0.181225
# 14     whole extended  0.181225
# 15           by heart  0.178516
# 16        knows these  0.176225
# 17       family knows  0.172491
# 18          and music  0.170925
# 19              songs  0.159900
# 20           movie or  0.155104
# 21              carol  0.152740
# 22          track and  0.150702
# 23    extended family  0.143575
# 24               sing  0.135704

# %% [markdown]
# # Word2Vec

# %%
# Using Google News Word2Vectors
'''

from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle

# in this project we are using a pretrained model by google
# its 3.3G file, once you load this into your memory 
# it occupies ~9Gb, so please do this step only if you have >12G of ram
# we will provide a pickle file wich contains a dict , 
# and it contains all our courpus words as keys and  model[word] as values
# To use this code-snippet, download "GoogleNews-vectors-negative300.bin" 
# from https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit
# it's 1.9GB in size.

model = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)
'''
# Out:
# '\n\nfrom gensim.models import Word2Vec\nfrom gensim.models import KeyedVectors\nimport pickle\n\n# in this project we are using a pretrained model by google\n# its 3.3G file, once you load this into your memory \n# it occupies ~9Gb, so please do this step only if you have >12G of ram\n# we will provide a pickle file wich contains a dict , \n# and it contains all our courpus words as keys and  model[word] as values\n# To use this code-snippet, download "GoogleNews-vectors-negative300.bin" \n# from https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit\n# it\'s 1.9GB in size.\n\nmodel = KeyedVectors.load_word2vec_format(\'GoogleNews-vectors-negative300.bin\', binary=True)\n'

# %%
import pickle

#if you do NOT have RAM >= 12GB, use the code below.
with open('word2vec_model', 'rb') as handle:
    model = pickle.load(handle)

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ### Observation: Here we got the model from the googles word2vec i.e for every word we have 300 dimension vector

# %%
type(model)
# Example we have taken is 'minions' for this we got 300 words vector 
model['minions'].shape
# Out:
# (300,)

# %%
model['computer']
# Out:
# array([ 1.07421875e-01, -2.01171875e-01,  1.23046875e-01,  2.11914062e-01,
#        -9.13085938e-02,  2.16796875e-01, -1.31835938e-01,  8.30078125e-02,
#         2.02148438e-01,  4.78515625e-02,  3.66210938e-02, -2.45361328e-02,
#         2.39257812e-02, -1.60156250e-01, -2.61230469e-02,  9.71679688e-02,
#        -6.34765625e-02,  1.84570312e-01,  1.70898438e-01, -1.63085938e-01,
#        -1.09375000e-01,  1.49414062e-01, -4.65393066e-04,  9.61914062e-02,
#         1.68945312e-01,  2.60925293e-03,  8.93554688e-02,  6.49414062e-02,
#         3.56445312e-02, -6.93359375e-02, -1.46484375e-01, -1.21093750e-01,
#        -2.27539062e-01,  2.45361328e-02, -1.24511719e-01, -3.18359375e-01,
#        -2.20703125e-01,  1.30859375e-01,  3.66210938e-02, -3.63769531e-02,
#        -1.13281250e-01,  1.95312500e-01,  9.76562500e-02,  1.26953125e-01,
#         6.59179688e-02,  6.93359375e-02,  1.02539062e-02,  1.75781250e-01,
#        -1.68945312e-01,  1.21307373e-03, -2.98828125e-01, -1.15234375e-01,
#         5.66406250e-02, -1.77734375e-01, -2.08984375e-01,  1.76757812e-01,
#         2.38037109e-02, -2.57812500e-01, -4.46777344e-02,  1.88476562e-01,
#         5.51757812e-02,  5.02929688e-02, -1.06933594e-01,  1.89453125e-01,
#        -1.16210938e-01,  8.49609375e-02, -1.71875000e-01,  2.45117188e-01,
#        -1.73828125e-01, -8.30078125e-03,  4.56542969e-02, -1.61132812e-02,
#         1.86523438e-01, -6.05468750e-02, -4.17480469e-02,  1.82617188e-01,
#         2.20703125e-01, -1.22558594e-01, -2.55126953e-02, -3.08593750e-01,
#         9.13085938e-02,  1.60156250e-01,  1.70898438e-01,  1.19628906e-01,
#         7.08007812e-02, -2.64892578e-02, -3.08837891e-02,  4.06250000e-01,
#        -1.01562500e-01,  5.71289062e-02, -7.26318359e-03, -9.17968750e-02,
#        -1.50390625e-01, -2.55859375e-01,  2.16796875e-01, -3.63769531e-02,
#         2.24609375e-01,  8.00781250e-02,  1.56250000e-01,  5.27343750e-02,
#         1.50390625e-01, -1.14746094e-01, -8.64257812e-02,  1.19140625e-01,
#        -7.17773438e-02,  2.73437500e-01, -1.64062500e-01,  7.29370117e-03,
#         4.21875000e-01, -1.12792969e-01, -1.35742188e-01, -1.31835938e-01,
#        -1.37695312e-01, -7.66601562e-02,  6.25000000e-02,  4.98046875e-02,
#        -1.91406250e-01, -6.03027344e-02,  2.27539062e-01,  5.88378906e-02,
#        -3.24218750e-01,  5.41992188e-02, -1.35742188e-01,  8.17871094e-03,
#        -5.24902344e-02, -1.74713135e-03, -9.81445312e-02, -2.86865234e-02,
#         3.61328125e-02,  2.15820312e-01,  5.98144531e-02, -3.08593750e-01,
#        -2.27539062e-01,  2.61718750e-01,  9.86328125e-02, -5.07812500e-02,
#         1.78222656e-02,  1.31835938e-01, -5.35156250e-01, -1.81640625e-01,
#         1.38671875e-01, -3.10546875e-01, -9.71679688e-02,  1.31835938e-01,
#        -1.16210938e-01,  7.03125000e-02,  2.85156250e-01,  3.51562500e-02,
#        -1.01562500e-01, -3.75976562e-02,  1.41601562e-01,  1.42578125e-01,
#        -5.68847656e-02,  2.65625000e-01, -2.09960938e-01,  9.64355469e-03,
#        -6.68945312e-02, -4.83398438e-02, -6.10351562e-02,  2.45117188e-01,
#        -9.66796875e-02,  1.78222656e-02, -1.27929688e-01, -4.78515625e-02,
#        -7.26318359e-03,  1.79687500e-01,  2.78320312e-02, -2.10937500e-01,
#        -1.43554688e-01, -1.27929688e-01,  1.73339844e-02, -3.60107422e-03,
#        -2.04101562e-01,  3.63159180e-03, -1.19628906e-01, -6.15234375e-02,
#         5.93261719e-02, -3.23486328e-03, -1.70898438e-01, -3.14941406e-02,
#        -8.88671875e-02, -2.89062500e-01,  3.44238281e-02, -1.87500000e-01,
#         2.94921875e-01,  1.58203125e-01, -1.19628906e-01,  7.61718750e-02,
#         6.39648438e-02, -4.68750000e-02, -6.83593750e-02,  1.21459961e-02,
#        -1.44531250e-01,  4.54101562e-02,  3.68652344e-02,  3.88671875e-01,
#         1.45507812e-01, -2.55859375e-01, -4.46777344e-02, -1.33789062e-01,
#        -1.38671875e-01,  6.59179688e-02,  1.37695312e-01,  1.14746094e-01,
#         2.03125000e-01, -4.78515625e-02,  1.80664062e-02, -8.54492188e-02,
#        -2.48046875e-01, -3.39843750e-01, -2.83203125e-02,  1.05468750e-01,
#        -2.14843750e-01, -8.74023438e-02,  7.12890625e-02,  1.87500000e-01,
#        -1.12304688e-01,  2.73437500e-01, -3.26171875e-01, -1.77734375e-01,
#        -4.24804688e-02, -2.69531250e-01,  6.64062500e-02, -6.88476562e-02,
#        -1.99218750e-01, -7.03125000e-02, -2.43164062e-01, -3.66210938e-02,
#        -7.37304688e-02, -1.77734375e-01,  9.17968750e-02, -1.25000000e-01,
#        -1.65039062e-01, -3.57421875e-01, -2.85156250e-01, -1.66992188e-01,
#         1.97265625e-01, -1.53320312e-01,  2.31933594e-02,  2.06054688e-01,
#         1.80664062e-01, -2.74658203e-02, -1.92382812e-01, -9.61914062e-02,
#        -1.06811523e-02, -4.73632812e-02,  6.54296875e-02, -1.25732422e-02,
#         1.78222656e-02, -8.00781250e-02, -2.59765625e-01,  9.37500000e-02,
#        -7.81250000e-02,  4.68750000e-02, -2.22167969e-02,  1.86767578e-02,
#         3.11279297e-02,  1.04980469e-02, -1.69921875e-01,  2.58789062e-02,
#        -3.41796875e-02, -1.44042969e-02, -5.46875000e-02, -8.78906250e-02,
#         1.96838379e-03,  2.23632812e-01, -1.36718750e-01,  1.75781250e-01,
#        -1.63085938e-01,  1.87500000e-01,  3.44238281e-02, -5.63964844e-02,
#        -2.27689743e-05,  4.27246094e-02,  5.81054688e-02, -1.07910156e-01,
#        -3.88183594e-02, -2.69531250e-01,  3.34472656e-02,  9.81445312e-02,
#         5.63964844e-02,  2.23632812e-01, -5.49316406e-02,  1.46484375e-01,
#         5.93261719e-02, -2.19726562e-01,  6.39648438e-02,  1.66015625e-02,
#         4.56542969e-02,  3.26171875e-01, -3.80859375e-01,  1.70898438e-01,
#         5.66406250e-02, -1.04492188e-01,  1.38671875e-01, -1.57226562e-01,
#         3.23486328e-03, -4.80957031e-02, -2.48046875e-01, -6.20117188e-02],
#       dtype=float32)

# %%
model.wv.similarity('woman','man')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-d8d2d053845e> in <module>()
# ----> 1 model.wv.similarity('woman','man')
#
# AttributeError: 'dict' object has no attribute 'wv'

# %%
model.wv.most_similar(positive=['woman', 'king'], negative=['man'])

# %%
# Train your own Word2Vec model using your own text corpus
import gensim

'''
i=0
list_of_sent=[]
for sent in final['Text'].values:
    filtered_sentence=[]
    sent=cleanhtml(sent)
    for w in sent.split():
        for cleaned_words in cleanpunc(w).split():
            if(cleaned_words.isalpha()):    
                filtered_sentence.append(cleaned_words.lower())
            else:
                continue 
    list_of_sent.append(filtered_sentence)
'''
# Out:
# "\ni=0\nlist_of_sent=[]\nfor sent in final['Text'].values:\n    filtered_sentence=[]\n    sent=cleanhtml(sent)\n    for w in sent.split():\n        for cleaned_words in cleanpunc(w).split():\n            if(cleaned_words.isalpha()):    \n                filtered_sentence.append(cleaned_words.lower())\n            else:\n                continue \n    list_of_sent.append(filtered_sentence)\n"

# %%
pickleIn = open("listOfSentAfterCleaninhHTML_Punc.pickle","rb")
list_of_sent = pickle.load(pickleIn)

# %%
print(final['Text'].values[0])
print("******************************************************************")
print(list_of_sent[0])
# Out:
# this witty little book makes my son laugh at loud. i recite it in the car as we're driving along and he always can sing the refrain. he's learned about whales, India, drooping roses:  i love all the new words this book  introduces and the silliness of it all.  this is a classic book i am  willing to bet my son will STILL be able to recite from memory when he is  in college
# ******************************************************************
# ['this', 'witty', 'little', 'book', 'makes', 'my', 'son', 'laugh', 'at', 'loud', 'i', 'recite', 'it', 'in', 'the', 'car', 'as', 'were', 'driving', 'along', 'and', 'he', 'always', 'can', 'sing', 'the', 'refrain', 'hes', 'learned', 'about', 'whales', 'india', 'drooping', 'i', 'love', 'all', 'the', 'new', 'words', 'this', 'book', 'introduces', 'and', 'the', 'silliness', 'of', 'it', 'all', 'this', 'is', 'a', 'classic', 'book', 'i', 'am', 'willing', 'to', 'bet', 'my', 'son', 'will', 'still', 'be', 'able', 'to', 'recite', 'from', 'memory', 'when', 'he', 'is', 'in', 'college']

# %% [markdown]
# Observation: We have converted every sentence into words and cleaned data by removing html tags, punc's

# %% [markdown]
# ## now training our own Word2Vec Model

# %%
# 1stparam -> list of words to be converted to vec
# min_count -> if word doesnt contain atleast 5 time we will not convert it to vec
# size -> no.of dimensions in a vec
# workers -> no. of cores in ur processor here its 4 so it will run on 4 cores

w2v_model = gensim.models.Word2Vec(list_of_sent, min_count=5, size=50, workers=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-c34279dc5b16> in <module>()
#       4 # workers -> no. of cores in ur processor here its 4 so it will run on 4 cores
#       5
# ----> 6 w2v_model = gensim.models.Word2Vec(list_of_sent, min_count=5, size=50, workers=4)
#
# NameError: name 'gensim' is not defined

# %%
w2v_model

# %%
words = list(w2v_model.wv.vocab)

# %%
print(len(words))

# %%
type(words)
words[0:10]

# %%
w2v_model.wv.most_similar('tasty')

# %%
w2v_model.wv.most_similar('like')

# %%
w2v_model.wv.similarity('woman','man')

# %% [markdown]
# ## Explanation: 0-> both are different words 1-> exact similar words

# %%
# getting feature names from bag of words, count_vect has bow from the BOW code

count_vect_features = count_vect.get_feature_names() 
count_vect_features.index('like')

# %%
count_vect_features[64055]

# %% [markdown]
# # Avg W2v, TFIDF-W2v

# %% [markdown]
# Avergae W2V is ntg but if given  a sentence it calculates the w2v of every word in the sentence and sum it up then divide by no.of words which give me the avg W2V of the 'SENTENCE'.<br>
#
# Note: Avg W2V is used to get the Sentence Vector.
# <br>
#
# TFIDF weighted W2V we will calc w2v of a word in the sentece and multiply it with tfidf of that word, this is done for every word and is summed up and divided by sum of tfidf of every word.
#
# Avg W2v = sum( w2v(wi) ) / (no.of words in the sentence)
# <br>
# Tf-IDF Weighted W2V = sum( ti * w2v(wi) ) / sum(ti)
# <br>
# Here 'ti' is tfidf of the word.

# %%
# average Word2Vec
# compute average word2vec for each review.
sent_vectors = []; # the avg-w2v for each sentence/review is stored in this list
for sent in list_of_sent: # for each review/sentence
    sent_vec = np.zeros(50) # as word vectors are of 50 length
    cnt_words =0; # num of words with a valid vector in the sentence/review
    for word in sent: # for each word in a review/sentence
        try:
            vec = w2v_model.wv[word]
            sent_vec += vec
            cnt_words += 1
        except:
            pass
    sent_vec /= cnt_words
    sent_vectors.append(sent_vec)

print(len(sent_vectors)) #no.of reviews
print(len(sent_vectors[0])) #no.of dimensions
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in true_divide
# 364171
# 50

# %%
import pickle

'''
pickle_out = open("BOW_tfidf_avgW2V_TfidfW2V.pickle","wb")

pickle.dump(count_vect,pickle_out) #BOW
pickle.dump(final_counts,pickle_out) #BOW

pickle.dump(tf_idf_vect,pickle_out) #tfidf
pickle.dump(final_tf_idf,pickle_out) #tfidf
pickle.dump(features,pickle_out) #tfidf feature/ unique words


pickle.dump(w2v_model,pickle_out) #custom W2V model
pickle.dump(words,pickle_out) #custom W2V model

pickle.dump(sent_vectors,pickle_out) #avg W2V model

'''
# Out:
# '\npickle_out = open("BOW_tfidf_avgW2V_TfidfW2V.pickle","wb")\n\npickle.dump(count_vect,pickle_out) #BOW\npickle.dump(final_counts,pickle_out) #BOW\n\npickle.dump(tf_idf_vect,pickle_out) #tfidf\npickle.dump(final_tf_idf,pickle_out) #tfidf\npickle.dump(features,pickle_out) #tfidf feature/ unique words\n\n\npickle.dump(w2v_model,pickle_out) #custom W2V model\npickle.dump(words,pickle_out) #custom W2V model\n\npickle.dump(sent_vectors,pickle_out) #avg W2V model\n\n'

# %%
import pickle
pickleIn = open("listOfSentAfterCleaninhHTML_Punc.pickle","rb")
list_of_sent = pickle.load(pickleIn)

# %%
pickle_in = open("BOW_tfidf_avgW2V_TfidfW2V.pickle","rb")
count_vect = pickle.load(pickle_in) #BOW
final_counts = pickle.load(pickle_in) #BOW

tf_idf_vect = pickle.load(pickle_in) #TFIDF
final_tf_idf = pickle.load(pickle_in) #TFIDF
features = pickle.load(pickle_in) #TFIDF

w2v_model = pickle.load(pickle_in) #w2v
words = pickle.load(pickle_in) #w2v

sent_vectors = pickle.load(pickle_in) #avg W2V
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# TF-IDF weighted Word2Vec
tfidf_feat = tf_idf_vect.get_feature_names() # tfidf words/col-names
# final_tf_idf is the sparse matrix with row= sentence, col=word and cell_val = tfidf

tfidf_sent_vectors = []; # the tfidf-w2v for each sentence/review is stored in this list
row=0;
for sent in list_of_sent[0:1000]: # for each review/sentence
    sent_vec = np.zeros(50) # as word vectors are of zero length
    weight_sum =0; # num of words with a valid vector in the sentence/review
    for word in sent: # for each word in a review/sentence
        try:
            
            vec = w2v_model.wv[word]
            
            # obtain the tf_idfidf of a word in a sentence/review
            tfidf = final_tf_idf[row, tfidf_feat.index(word)]
            
            sent_vec += (vec * tfidf)
            
            weight_sum += tfidf
        except:
            pass
    sent_vec /= weight_sum
   
    tfidf_sent_vectors.append(sent_vec)
    row += 1

# %%
pickle_out = open("WiightedTfidfW2V.pickle","wb")

pickle.dump(tfidf_sent_vectors,pickle_out) #tfidf weighted w2v model



pickle_out.close()

# %%
 len(tfidf_sent_vectors)
# Out:
# 1000

# %%
tfidf_sent_vectors
# Out:
# [array([-0.29627643, -0.51362031, -0.58506384,  0.0860804 ,  0.72537245,
#         -0.35187534,  0.79041181,  0.01443852,  0.76386532, -0.37197787,
#          0.17360276,  0.04758323,  0.23676344, -0.39042325, -0.08103206,
#          0.35537419, -0.85508999,  0.03277539, -0.76552184,  0.13424716,
#          0.30303481, -0.09814295, -0.10739398,  0.83406531, -1.41693885,
#         -0.46265499, -0.33612626, -0.43161811, -0.04409374, -0.01153882,
#         -0.11547316, -0.4279345 , -0.10832784, -0.65109224,  0.48110606,
#          0.18781087, -0.7394375 , -0.07746156,  0.64385304, -0.07342261,
#         -1.02265508, -0.25985266,  0.07963824, -0.44332141,  0.35927659,
#          0.31822868,  0.51050469,  0.85788021,  0.21028271,  0.93582324]),
#  array([ 0.54159437, -1.0764013 ,  0.48108009, -0.39473469,  0.59594002,
#         -0.27888179,  0.53715707, -0.41475229,  0.38884871, -0.25067827,
#          0.39091359,  0.29503965,  0.02602744,  0.33568362, -0.12182654,
#          0.65016806, -0.7719431 ,  0.86089429, -0.62763092, -0.71860231,
#          0.44524938, -0.43171036,  0.44025438,  0.20339992, -1.53182039,
#          0.07302302, -0.46942072, -0.23074945,  0.38931314,  0.16810026,
#          0.43584418, -0.55509115,  0.47253393, -0.53247003,  0.03980255,
#          0.12076495, -0.13741906, -0.51414529,  0.30523603,  0.72506427,
#         -0.9888479 ,  0.62447094,  0.11525687, -0.09332133, -0.0153452 ,
#          0.07948367,  0.26749938, -0.19853864, -0.15329175,  0.34661347]),
#  array([-0.40549445, -0.55512539,  0.63156922, -0.02820587,  1.14901699,
#         -0.24989413,  0.60693892, -0.58901115, -0.06300671, -0.53912443,
#         -0.81507198,  0.34510577, -0.18098459,  0.13501343, -0.34045116,
#          0.49182867,  0.57873473,  0.11033456, -0.96348922, -1.04017686,
#         -0.08198775,  0.17880186,  0.1381025 ,  0.87338591, -0.91213151,
#         -0.13109372, -0.78067581,  0.14079867,  0.03851934, -1.28910888,
#          0.34810093, -0.15763662,  0.34307517, -0.57991673, -0.06658711,
#          0.11870544, -0.85166536, -0.08165682,  0.20404579,  0.38403526,
#         -0.61775163, -0.22875857,  0.64101704, -0.34577055,  0.35406451,
#          0.59672878,  0.06227757,  0.30738946,  0.13226847,  0.95069192]),
#  array([ 0.12069961, -0.59022825, -0.29301565, -0.77275905,  0.8647213 ,
#         -0.43494121,  0.406572  , -0.66313463,  0.31701027, -0.43410613,
#          0.17695343,  0.32168711,  0.43584808,  0.3678613 ,  0.33034922,
#          0.42342313, -0.67306745,  0.82463357, -0.82300672, -0.1502288 ,
#         -0.200372  , -0.10459613, -0.00637024,  0.89991164, -1.42874283,
#          0.44329983, -0.56078657,  0.41675162,  0.30279331, -0.34154045,
#         -0.15241381, -0.15962381,  0.16615841, -0.4495057 , -0.05005223,
#         -0.03239722, -0.35425562, -0.62153886, -0.21192498,  0.44382017,
#         -0.8115898 ,  0.34849229,  0.10368704, -0.29515641,  0.35628413,
#         -0.22137796,  0.25513727,  0.12837259, -0.45644084,  0.22652735]),
#  array([-0.13825081, -0.65864834, -0.02352022, -0.40700931,  0.86930504,
#         -0.02719284,  0.99423315, -0.84626359,  0.66180013, -1.14424749,
#         -0.77765055,  0.48022693,  0.25196118, -0.05764382, -0.35898717,
#          0.36219195, -0.47085191, -0.09603469, -0.98385977, -0.14856598,
#         -0.50465015,  0.19393305,  0.10020871,  0.91126815, -1.07632605,
#         -0.28629159, -0.24415386, -0.37820411, -0.24693325, -0.42005379,
#         -0.06975138, -0.14670512,  0.18082955, -0.692783  ,  0.0769964 ,
#          0.0277726 , -1.28611586, -0.50451676, -0.20542025, -0.3589197 ,
#         -0.80474489, -0.13913495,  0.19719597, -0.70865209,  0.46580023,
#          0.7584305 ,  0.46121177,  0.79691963,  0.39118942,  1.2744939 ]),
#  array([ 0.18679689, -0.32260832, -0.10766888, -0.65741674,  0.62961814,
#         -0.04877908,  0.35086489, -0.21260258,  0.55092071, -0.73842897,
#          0.09086545,  0.10452955,  0.16282878,  0.61927187,  0.41826413,
#          0.07571255, -0.46406654,  0.02486095, -0.30061969,  0.05039486,
#          0.04963497, -0.10229814,  0.02182192,  0.15379117, -0.71332621,
#          0.04781708,  0.01523917,  0.67151943,  0.29938146, -0.50356464,
#          0.15891902, -0.26425264,  0.0315361 , -0.31061036,  0.43478583,
#         -0.09367286,  0.20061139, -0.70062425,  0.35824286,  0.22192861,
#         -0.46502383,  0.3441151 , -0.06585626, -0.36351212, -0.20699362,
#         -0.52375075,  0.04339234, -0.35824522, -0.63633314,  0.7189037 ]),
#  array([-0.3861719 , -0.66220124, -0.39749213, -0.5783139 ,  0.19361967,
#         -0.24873593,  0.9461312 , -0.29529136,  0.70934803, -0.98311699,
#         -0.29705212,  0.48287551, -0.31655498, -0.51953168, -0.3516807 ,
#          0.03933968, -0.60398773,  1.01388253, -0.98120684,  0.14701018,
#         -0.57195124,  0.36359724,  0.42694298,  0.8291693 , -0.87328221,
#         -0.10291592, -0.17577664, -0.26259626, -0.63743586, -0.03184278,
#         -0.50138256,  0.38865901, -0.02612539, -0.79579246,  0.22549368,
#         -0.1253825 , -0.42106793, -0.41717124, -0.11139895, -0.0107881 ,
#         -0.75179548, -0.41678633, -0.03596977, -0.4043392 ,  0.15289259,
#          0.18692804,  0.41829993,  0.03467689,  0.18846779,  0.892217  ]),
#  array([-0.2663991 , -0.82951984,  0.70025842,  0.25110509,  1.17731549,
#         -0.37748843,  0.61620363,  1.2742081 , -0.08659886, -0.61392458,
#          0.44809803,  0.58920894,  0.18120079, -0.10487329, -0.8230606 ,
#          1.42154363, -1.09483853,  0.79110702, -1.07239246, -0.82721519,
#          0.7826327 ,  0.23253711, -0.5413285 ,  0.74685793, -1.78128251,
#         -0.86770708, -1.30586048, -0.32752508,  1.07861391, -1.04997064,
#         -0.23588217, -1.3136278 ,  0.4380082 , -1.17846901,  0.51088759,
#          0.43154469, -0.63997123, -1.56204667,  1.16179292, -0.24587161,
#          0.09863587,  0.061905  , -0.34735055, -0.86000421,  0.72910455,
#          0.08693312,  0.52262767,  0.90495238, -0.60059   ,  0.27321713]),
#  array([-0.01800823, -0.46224061,  0.1656132 , -0.89680958,  0.50118293,
#         -0.17488645,  0.31343904,  0.00302236,  0.32581529, -0.17941954,
#          0.52582742,  0.06378132,  0.73952043,  0.38797777,  0.23598372,
#          0.22886907, -0.68622577,  0.26980593, -0.075311  ,  0.51469347,
#          0.09775162, -0.06512336, -0.2590906 ,  0.64085852, -0.77415251,
#          0.19543379, -0.23865154,  0.12008069,  0.58895162,  0.11610726,
#         -0.44216027,  0.27947355, -0.1859194 , -1.09667089, -0.15519435,
#          0.27214975, -0.52528813, -0.45484983, -0.10259306, -0.23274161,
#         -0.49157505, -0.15543865, -0.06674986, -0.21982943,  0.07074799,
#          0.40466924,  0.1967683 , -0.02181279, -0.49756632,  0.43744362]),
#  array([-5.69844920e-01, -3.89303866e-01, -3.44240570e-01,  3.33924673e-02,
#          7.56854241e-01, -1.62694566e+00,  1.41870183e+00, -7.50743592e-03,
#          3.75909873e-01, -1.30362513e-01, -2.11540610e-01, -3.61695586e-01,
#          2.08120740e-01,  1.56051970e-01,  2.47837234e-01,  1.89768374e+00,
#         -1.05837015e+00,  1.90184348e-01, -9.16757757e-01, -1.01362333e+00,
#          4.12460756e-01,  7.21138922e-03, -4.10312582e-02,  1.34136729e+00,
#         -1.54928298e+00, -1.43621782e+00, -2.06287459e-03, -8.99277609e-01,
#          5.16459500e-01, -6.83771922e-01,  2.71361677e-01, -8.44560583e-01,
#          3.45830977e-01, -6.59085390e-01, -2.86151700e-01,  6.53768106e-01,
#         -5.85716007e-01,  5.23218671e-01,  6.87497549e-01,  5.83402300e-02,
#         -1.06041331e+00, -2.88320206e-01, -8.55328862e-02, -7.64267872e-01,
#          1.21536351e+00,  1.13208151e-03,  2.58703532e-02,  4.07776943e-01,
#         -9.59371989e-01,  1.03972368e+00]),
#  array([-0.09065474, -0.44389421,  0.5092689 ,  0.31394183,  0.45229382,
#          0.17375109,  0.61186601, -0.11554453,  0.83443364,  0.02142977,
#          0.14817788, -0.14256994,  0.71777255,  0.06730705,  0.35406358,
#          0.41087338, -0.41621544, -0.06142384,  0.04031067,  0.00708904,
#         -0.04152356, -0.4599352 ,  0.27905948,  0.10069113, -1.04588944,
#         -0.2471442 , -0.22913077, -0.32950502,  0.54908502, -0.11592753,
#          0.35517372,  0.02228436, -0.18683229, -0.80588427, -0.30725878,
#          0.63119034,  0.18231131, -0.49005038,  0.95946364, -0.17746734,
#         -0.96324381, -0.3478828 ,  0.27997629, -0.10506951, -0.21139109,
#          0.37138939,  0.3773062 ,  0.38960898, -0.23121765,  0.9397978 ]),
#  array([-0.26713228, -0.38790345,  0.3030599 , -0.57539595,  0.07834238,
#          0.38023164,  0.34343147, -0.1256845 , -0.067075  , -0.14379842,
#          0.57148838,  0.55181933, -0.04649553,  0.48018324, -0.29248696,
#         -0.20218155, -0.72359448,  0.78155774, -0.7872591 , -0.13024184,
#          0.02322626,  0.05356419,  0.28916477,  0.12034834,  0.32591231,
#          0.4175734 , -0.28847339, -0.24905056,  0.06193378, -0.47035701,
#         -0.25167261,  0.13435728, -0.02721837, -0.49372207,  0.36830658,
#          0.09693666, -0.73525685, -0.52408389,  0.00227926,  0.57219683,
#         -0.7799459 ,  0.20466977, -0.4909879 ,  0.44313238, -0.14092742,
#          0.33109492,  0.11277318, -0.22719323,  0.22288833,  0.02225582]),
#  array([-0.33348976,  0.51177284,  0.4658054 ,  0.8590389 , -0.3825983 ,
#         -0.90260796,  1.25900609, -1.70183421,  2.0801616 , -2.13945557,
#         -1.2022583 ,  0.47128006,  0.26695271,  0.37481132, -1.45005004,
#         -0.41097741, -1.67060528,  1.04986961,  0.0355568 , -2.0451018 ,
#         -0.16756463,  1.12450162,  0.9944624 ,  1.02937641, -1.17009159,
#          2.24021423, -0.37289424, -0.87451579,  0.32482159, -2.0558548 ,
#         -2.16997311,  1.17895418,  1.04082931,  0.4418746 , -0.21615014,
#         -0.14603681, -0.06986731, -0.77741245, -0.0026277 , -0.58069272,
#         -1.48897699,  0.06018488, -0.87819664, -0.66694904,  1.21338391,
#          0.32381681, -0.05485333,  0.79283676, -1.02902879, -1.03031179]),
#  array([-0.2103094 , -0.79188653, -0.70734396, -0.11890141,  1.08902124,
#          0.5867525 , -0.21994936,  0.34055603, -0.13980336, -0.53986494,
#         -0.22069224, -0.40542985,  0.10881354,  1.40869   , -0.25460409,
#          0.97513442, -1.62973938,  0.96635219, -0.63511409, -1.76217872,
#          0.67110546,  0.21807214,  0.51649784,  1.02985313, -0.94529003,
#         -1.07468809, -0.72895517,  0.56998018, -0.35488236, -0.18402252,
#          0.34831347, -0.86362103,  0.41509069, -0.79818073,  0.31571783,
#         -0.37915368,  0.02782969, -0.93312218,  0.92315508, -0.25332901,
#         -0.50980056, -0.11874855,  0.08566798, -0.26371263,  0.83233535,
#         -0.15819072, -0.45415332,  0.78148437, -1.31739116,  1.39622161]),
#  array([ 0.066711  , -0.63818466, -0.47603456,  0.56447264,  0.796567  ,
#         -1.22325355,  1.03870053,  0.07045496, -0.02426709, -0.91886273,
#          0.70255668,  0.1470285 ,  0.28205136, -0.30661483, -0.07667583,
#          1.13906482, -0.80090744,  0.02135781, -1.46248423, -0.71320615,
#          0.43636099,  0.59756087, -0.71703406,  1.53744616, -1.09592899,
#         -1.10607933, -0.70008321, -0.38357189,  0.10604515, -0.77109519,
#         -0.56336137, -0.76178748,  0.22652726,  0.42494585,  0.71965793,
#          0.4022044 , -0.80697035, -0.89990155,  1.000236  ,  0.0801109 ,
#         -0.98460101, -0.41403623, -0.19155928, -0.40942844,  0.48912928,
#         -0.40460284,  0.73253497,  1.7894454 , -0.32967633,  0.53762825]),
#  array([-0.25450413, -0.71318738, -0.47010415,  0.00518833,  1.00267489,
#          0.02324   ,  0.93931762, -0.52525108,  0.82795462, -1.01079932,
#         -0.08951258,  0.40835335,  0.13461911, -0.32032873, -0.10989824,
#          0.3133211 , -1.13160148,  0.35906381, -0.81804302, -0.29079627,
#          0.14289458,  0.11259101, -0.04484386,  1.42111971, -1.83623292,
#         -0.66129293, -0.89959114, -0.28582721,  0.02403135, -0.39115843,
#         -0.2898746 , -0.55260524,  0.19375137, -0.65248807,  0.35946224,
#          0.14588929, -1.00882801, -0.66287238,  0.451832  , -0.12773408,
#         -1.08263043, -0.39710678, -0.20163512, -1.002508  ,  0.64393205,
#          0.480198  ,  0.79999368,  1.17001149,  0.18193381,  1.05107675]),
#  array([-0.33481038, -0.40720412, -0.35000955, -0.78841299,  0.22051152,
#         -0.43263501,  0.20517677, -0.50472024, -0.09813953, -0.32136994,
#         -0.60194586, -0.44340092,  0.24439963,  0.53342169,  0.12676287,
#         -0.00558601, -0.43119608,  0.63811025, -0.11130376, -0.64643798,
#         -0.86241135, -0.38207787,  0.45026113,  0.79891985, -0.98146601,
#          0.04350634,  0.23262527,  0.60618929,  0.09264165, -0.50646354,
#          0.44848744,  0.76188492,  0.24961434, -0.99750871,  0.38371951,
#         -0.01863627, -0.2361692 ,  0.04894956, -0.01615443,  0.27973792,
#         -0.3466231 , -0.13077773, -0.27866554, -0.37410881, -0.14302273,
#          0.08876455, -0.24012515,  0.06423493, -0.3199215 ,  0.37382576]),
#  array([-0.23326161, -0.5981177 , -0.20677231, -0.44277217,  0.97738836,
#         -0.51792768,  0.34916033, -0.36083561,  0.22223503, -0.56016165,
#         -0.78965348,  0.18605235,  0.66232123,  0.62598383,  0.19122316,
#          0.39142035, -0.14114732,  0.24170361, -0.72522148, -0.86442758,
#         -0.4911641 ,  0.05472565,  0.24513044,  0.86023523, -1.52894866,
#         -0.19434354, -0.54995075,  0.15382779,  0.0595771 , -1.22109454,
#          0.22649272,  0.24878694,  0.52711632, -0.73750238,  0.31621106,
#          0.05346077, -0.4912562 , -0.26762617,  0.19393893,  0.30121037,
#         -0.43175591,  0.10241244,  0.34517447, -0.12457744,  0.4917144 ,
#          0.48466334, -0.09806767, -0.05243407, -0.34371618,  1.00739803]),
#  array([-0.28479902, -0.17484107,  0.07630344, -0.27688328,  0.45563857,
#         -0.47940843,  0.65033576, -0.0061528 ,  0.63942454, -0.51228118,
#         -0.19337868,  0.46166776,  0.0848008 ,  0.24159102, -0.08850217,
#          0.50260086, -0.62891564,  0.41311405, -0.66446378, -0.44166388,
#         -0.26644819, -0.17161142, -0.22861688,  0.5607013 , -0.15611138,
#         -0.24594796, -0.4662618 , -0.29176471,  0.12711981,  0.1251103 ,
#          0.34086575, -0.17260913, -0.15563387, -0.95298853,  0.43758014,
#          0.09613429, -0.65925103, -0.35965139,  0.7367825 ,  0.08424512,
#         -0.58906118, -0.40786034, -0.54889869,  0.18859578,  0.16046217,
#          0.11272824,  0.06652455,  0.51336671, -0.39821202,  0.33104914]),
#  array([-0.27440536,  0.58505049,  0.33234744, -0.30798074, -0.09864642,
#         -0.1781042 ,  0.57693607, -0.11977888,  0.45020165, -0.80284082,
#         -0.24370234,  0.16050223, -0.17147053,  0.42574868, -0.06959757,
#         -0.41446256, -1.33399037,  0.6833595 , -0.59543805,  0.13493044,
#         -0.34753873,  0.38239444,  0.30193693,  0.72939561, -0.3572615 ,
#          0.10838896,  0.02844925, -0.06356866, -0.40295715, -0.38691799,
#         -0.93574879,  0.9683954 , -0.09689964, -0.58272099,  0.91617113,
#          0.28673357, -0.63355098, -0.58526449,  0.312052  , -0.68515344,
#         -1.1511195 , -0.53399233, -1.08937647, -0.05359222, -0.15144573,
#         -0.23437278, -0.0658529 ,  0.29101728,  0.4019317 , -0.08291391]),
#  array([ 0.14498851, -1.10677832, -0.25489692, -0.83188632,  1.00433264,
#          0.49427393,  0.05082163,  0.17850861,  0.33665456, -0.48522162,
#          0.28733497, -0.09539587, -0.05169535,  0.72426039,  0.56410841,
#          0.10009184, -1.1614258 ,  0.72513202, -0.21480755, -0.63467818,
#         -0.98309341, -0.21616164,  0.21561973,  0.84950622, -0.73926864,
#          0.26201659, -0.26186199,  0.6515427 , -0.18906045, -0.18926517,
#          0.71581345,  0.47388851,  0.55622962, -0.98363419,  0.27543385,
#         -0.72575747,  0.50566601, -0.23703933, -0.10931746,  0.06674367,
#         -0.1000097 ,  0.05979192, -0.07766237, -0.19075476,  0.42992836,
#          0.09891104,  0.08111275, -0.22716254, -0.61092666,  0.51673307]),
#  array([-0.72806916, -1.28021204,  0.92184578, -0.67791573,  0.41852023,
#         -0.98395109,  2.57195743,  0.41700342,  0.50095202, -0.91361113,
#          0.48081668,  0.70415352, -0.38615273,  0.07334574,  0.41660814,
#          0.18496543, -1.27310757,  1.44287039, -1.16195383,  0.34670311,
#         -0.03537128,  1.1800472 , -0.27502817,  1.39367566,  0.27879745,
#         -0.08094371, -0.15862998, -0.05834323, -0.37258561,  0.0617776 ,
#         -0.81193669,  0.47120625, -0.49169407,  0.39726054, -1.26476972,
#         -0.30301704, -0.43023843, -1.30219449,  0.07659115,  0.1473803 ,
#         -1.51127747,  0.48415232, -0.34186283, -0.80413281,  0.17476176,
#         -0.10583234,  0.78762157,  0.76780413, -0.17240832,  0.32057191]),
#  array([ 0.44211452,  0.0465634 ,  0.19289582, -1.08860964,  0.3636966 ,
#         -0.14634385, -0.22497428, -0.66077385,  0.10918789, -0.59517595,
#          0.30665655,  0.09889783,  0.08962778, -0.27238155,  0.47779792,
#         -0.24634746, -0.36768945,  0.02504474, -0.11083982, -0.6799357 ,
#          0.22834516, -0.08714578,  0.03966208,  0.54611468, -0.50609436,
#          0.26181024, -0.2948151 , -0.33846286,  0.9856851 , -0.58140533,
#          0.09799237,  0.41954056,  0.17821164, -0.6977073 ,  0.32938185,
#          0.12200056,  0.01895054, -0.49958901, -0.16636532,  0.62070975,
#         -0.50358338,  0.03957   , -0.06482515,  0.30247689,  0.08489898,
#         -0.29469633, -0.46291937, -0.26962821, -0.16265596, -0.44670296]),
#  array([-0.34145621, -0.74097587,  0.27871231, -0.08296255,  0.13458712,
#          0.08541641,  0.33247286, -0.52985556, -0.11350266, -0.88983941,
#         -0.22388681,  0.63059853,  0.00405451,  0.73649144,  0.82568902,
#         -0.2179791 , -0.31477858,  0.92978835, -0.79986837,  0.05761369,
#         -0.13706771, -0.35411346, -0.39086866,  0.50597572, -0.09818759,
#         -0.81863129,  0.33219295,  0.07717025, -0.99582956,  0.06354056,
#         -0.35138569, -0.07973266, -0.02364664, -0.71223887, -0.36054134,
#          0.3943659 , -0.95751499, -0.99702858,  0.25147555,  0.24059631,
#         -0.87667042, -0.21575211,  0.41890802, -0.2918382 , -0.14930279,
#          0.04460781,  0.58491058, -0.01159171, -0.61355797,  0.26832682]),
#  array([ 0.02918119, -0.577328  ,  0.15456242, -0.46558495,  0.91533672,
#          0.07973733,  0.3179658 , -0.08162491, -0.2678437 , -0.9971748 ,
#          0.31678163,  0.25077052,  0.07254415,  0.45993143,  0.00934507,
#          0.4687221 , -0.69156715,  0.30976778, -0.32109973, -0.95241805,
#          0.22606285,  0.21378213,  0.16981999,  0.82047352, -0.71627446,
#         -0.24454706, -0.33708763, -0.05749208,  0.40543487, -0.24088411,
#         -0.27247441, -0.36980915,  0.12294604, -0.95731468,  0.06845625,
#         -0.03187669, -0.13151268, -0.12221586, -0.00972663, -0.25676619,
#         -0.35922845,  0.0387685 ,  0.26541671, -0.49565392,  0.34816909,
#         -0.26845057,  0.03008028,  0.25398449, -0.60762317,  0.29725927]),
#  array([-3.21760575e-01, -8.37629352e-01, -4.19197277e-01, -8.58657576e-02,
#          8.01597555e-01, -1.83121602e-01,  4.06442322e-01,  6.08546112e-02,
#          4.54114947e-01, -1.11876322e+00, -5.95537744e-02,  6.25411100e-01,
#          1.25425479e-01,  2.02042813e-01, -5.23386362e-01,  5.10913691e-01,
#         -6.36210237e-01,  5.72413116e-01, -1.36776627e+00, -7.74014516e-01,
#         -1.03938418e-01,  4.08059337e-01,  4.38267120e-02,  1.38419711e+00,
#         -1.77219500e+00, -3.49043862e-01, -4.46431025e-01, -2.65066072e-01,
#         -1.23558166e-01, -4.42921062e-01, -1.00695209e-01, -4.26677263e-01,
#          3.29954798e-01, -6.19250259e-01,  1.46940833e-01,  4.14399143e-01,
#         -7.88906611e-01, -3.98732995e-01,  6.72966136e-01, -8.17652361e-02,
#         -8.63847907e-01, -2.04329765e-01, -2.44318533e-01, -3.61847564e-01,
#          7.18441345e-04,  6.93038254e-01,  4.86089666e-01,  8.65660395e-01,
#          4.08379978e-01,  1.17003524e+00]),
#  array([-0.3417289 , -0.75488463, -0.08226416, -0.19382692,  0.35496144,
#         -0.4100753 ,  0.96094831, -0.22551276,  0.15419895, -0.7693577 ,
#         -0.11172884, -0.03565523, -0.17477008, -0.31281491,  0.11445795,
#          0.31040274, -0.51787184,  0.64867995, -0.88500792,  0.19569064,
#         -0.54540089, -0.06546463,  0.1260049 ,  0.8068631 , -1.30620228,
#         -0.1273074 ,  0.01191523, -0.01609959, -0.2565611 ,  0.08193423,
#         -0.33817207,  0.07733886, -0.34812954, -0.99026551,  0.06786578,
#          0.12689075, -0.47359289, -0.86027176,  0.2779545 , -0.20766199,
#         -0.98816669, -0.10596567,  0.28389498, -0.22703739,  0.30402386,
#          0.0768837 ,  0.10844613, -0.24525274,  0.06171032,  0.87735301]),
#  array([-0.11339278,  0.02466964, -1.0288555 , -0.54263867,  0.82945076,
#         -0.16175132,  0.9178963 ,  1.06244271,  1.07436805, -0.6103846 ,
#         -0.04371184,  0.03010403, -0.27666087,  0.09718033,  0.42082123,
#          1.22442438, -0.53602363, -0.26404282, -0.33383786, -0.93962456,
#         -0.00984943,  0.58932196,  0.59841409,  0.39500181, -0.56034513,
#         -0.49618026, -0.07077034,  0.12662078,  0.53109075, -1.46679227,
#         -0.10128095, -0.82188403, -0.22726403, -1.03485956,  0.30306792,
#          0.02461982,  0.41278079, -0.24544472,  0.02228369,  0.3211712 ,
#         -0.39614752,  0.13242073, -0.51477591, -0.90063477, -0.00735293,
#          0.0959916 , -0.58208166, -0.79957025, -0.33405339,  0.88777767]),
#  array([ 0.12010773, -0.36152655, -0.40220653, -0.71209382,  0.56537887,
#         -0.20941906,  0.37711668, -0.65529382,  0.36009406, -0.73155601,
#         -0.17067999,  0.24278834,  0.38025389,  0.0662882 , -0.0214458 ,
#         -0.06644713, -0.51043873,  0.44961707, -0.74300892, -0.044296  ,
#         -0.4036042 , -0.09240322,  0.15569011,  0.84401903, -1.04077182,
#         -0.07242068, -0.25184269,  0.10986459,  0.21001166, -0.52944641,
#         -0.43269426,  0.32120454,  0.23837429, -0.90801934,  0.23065989,
#         -0.19949991, -0.87428777, -0.57476908, -0.19154927,  0.04163772,
#         -0.620201  , -0.11429023, -0.00537503, -0.72104432,  0.28400844,
#          0.09047659,  0.35110173,  0.33724742, -0.13925028,  0.64172421]),
#  array([-0.088791  , -0.64820028,  0.24758997, -0.3335062 ,  0.45102344,
#         -0.25740892,  0.48095329, -0.27374514,  0.33413948, -1.25643282,
#          0.01998176,  0.34849713, -0.10140617, -0.50950031,  0.1409301 ,
#         -0.24174203, -1.16390953,  0.2882139 , -0.69822119, -0.12791313,
#         -0.45312078, -0.35295869,  0.14451026,  1.19156794, -0.91706757,
#         -0.48336982, -0.2248394 , -0.25488496, -0.30955706, -0.41691126,
#         -0.31903299, -0.10976237,  0.0205318 , -0.77642775,  0.33925974,
#          0.32870618, -0.63730392, -0.61248453,  0.29022237, -0.6641157 ,
#         -0.81490117, -0.54825129, -0.64180071, -0.2817046 , -0.00148834,
#          0.45041144,  0.61732661,  0.24795983,  0.3898812 ,  0.5072786 ]),
#  array([ 1.11515077e-01, -5.30357581e-01, -6.47279101e-01, -6.51726113e-02,
#          3.48731306e-01, -2.32179820e-01,  6.59505042e-01,  2.06817921e-01,
#          1.03431092e+00, -1.95243454e-01, -4.63527695e-01,  6.01133860e-01,
#         -3.06000009e-01, -4.70509311e-01,  2.86889366e-02,  3.16773962e-01,
#         -4.21244015e-01,  9.05772945e-02, -1.08563992e+00, -5.65852283e-01,
#         -5.12270362e-01,  8.09865130e-01,  7.85269491e-01,  1.01804943e+00,
#         -8.93571897e-01, -3.80250895e-01, -7.01175133e-01, -1.25429639e-02,
#         -1.29560677e-01, -6.94929793e-01, -7.81837467e-03, -9.49674288e-01,
#          1.82956103e-02, -5.43998091e-01,  4.20833143e-01,  2.26090379e-01,
#         -4.80617253e-01, -1.05445212e+00, -6.41278571e-04,  4.49803723e-01,
#         -6.90073110e-01,  3.61788904e-01, -2.10656141e-01, -4.41243364e-01,
#          3.37321138e-01,  6.22992608e-01, -9.78814484e-02,  6.26706206e-01,
#          3.87371317e-03,  8.61638553e-01]),
#  array([ 0.01834807, -0.9345717 , -1.43358696, -1.1695245 ,  0.43423765,
#          0.68265804, -0.33919913, -0.79607976, -0.13303874, -0.75280227,
#         -0.26475333, -0.23555575,  0.577293  ,  1.5840199 ,  0.51066297,
#         -0.00717077, -1.34360564,  1.11382303, -0.38936888, -0.71140412,
#          0.02005552, -0.2789261 ,  0.25852606,  1.0139055 , -1.26825094,
#         -0.48670706,  0.30644795,  1.07000192, -0.51911225,  0.49223373,
#          0.10285464,  0.22200794,  0.04757677, -1.0468819 , -0.02149759,
#         -0.32767303,  0.12782593, -1.55216903, -0.00270356, -0.38962119,
#         -0.87251017, -0.62045249,  0.44491089, -0.01435009,  0.85429927,
#         -0.63813231, -0.67482793,  0.11039476, -1.24042065,  1.43666422]),
#  array([-3.80245721e-01, -6.39754143e-01, -8.22465761e-01,  1.64585491e-01,
#          2.50481524e-01, -4.92499732e-01,  1.22820255e+00, -3.50041796e-01,
#          6.98454360e-01, -1.42538467e+00,  1.42033550e-01,  7.03434725e-01,
#          1.44921061e-04, -1.26716413e-01, -2.66373315e-01,  2.91666996e-01,
#         -1.09895291e+00,  9.31747961e-01, -1.01212069e+00,  2.68434529e-01,
#         -2.07356116e-01, -1.55119050e-01, -2.04500333e-01,  9.80248757e-01,
#         -1.28430346e+00, -2.29417242e-01, -3.16008636e-01, -5.49822281e-02,
#         -8.19507070e-01,  1.61656237e-01, -5.70020441e-01,  1.91016715e-01,
#          2.70035750e-01, -2.92084361e-01,  6.31681426e-01,  1.11103821e-01,
#         -8.15176852e-01, -1.17913038e+00, -3.04297448e-01, -3.21617176e-01,
#         -1.39301744e+00,  2.34209949e-01, -3.97202371e-01, -4.04860415e-01,
#          7.38789485e-01,  1.08540998e-01,  6.48910567e-01,  8.34572094e-01,
#          5.67557353e-02,  7.24048698e-01]),
#  array([ 0.00905941, -0.31182175, -0.3705635 , -0.41650949,  0.36753817,
#         -0.14801214,  0.54715946,  0.25440847,  0.49779341, -0.42052993,
#         -0.46386104, -0.01421356,  0.08730862, -0.69296613, -0.17118577,
#          0.01809879, -0.8147384 ,  0.48719991, -0.42304121,  0.0529458 ,
#         -0.21110601,  0.33941573,  0.16478599,  0.5504747 , -1.04739022,
#         -0.7816384 , -0.18951021, -0.12441197, -0.24003938, -0.30062717,
#         -0.49807392,  0.41784884,  0.23665573, -0.97573443,  0.8246989 ,
#          0.01960876, -0.57692368, -0.416768  ,  0.08961136, -0.41496059,
#         -0.53603994, -0.24619959,  0.15877817, -0.57904673,  0.96341632,
#         -0.24155063,  0.11574069,  0.63395777,  0.31701173,  0.76513135]),
#  array([-1.06491341, -0.43228749, -0.42772806, -1.03929754,  0.07194183,
#          0.39608509,  0.39239519, -0.48862605, -0.64180606,  0.18989772,
#          0.73233772,  0.02040525,  0.61673279,  1.74269507,  1.1047915 ,
#         -0.81728353, -1.95815336, -0.02533223, -0.22559004,  0.54642546,
#         -0.82529976, -0.30248644,  0.08472693,  0.0704636 , -1.47097014,
#          1.42865985, -0.47003679,  0.77615636, -0.2166961 ,  0.40631496,
#         -0.21572517,  0.79492447,  0.25337564, -2.28633084, -0.0097193 ,
#         -0.41561165, -0.46323749,  0.36722693, -0.04013064, -0.66506521,
#          0.65248997, -0.07035981, -0.41453657, -0.57461214,  0.15405794,
#         -0.43150077, -1.18848931, -0.57729427, -0.08492312, -0.17686221]),
#  array([-0.52928613, -0.5341682 ,  0.44128165, -0.06192464, -0.16783882,
#         -0.27069432,  0.55775905, -1.66831393,  0.0135617 , -0.30548093,
#         -1.05374666,  0.72441592, -0.31379663,  0.1688441 , -1.19261061,
#          1.17583667, -1.27181678,  0.11088273, -1.54638288, -0.58506087,
#          0.12645961, -0.15671562,  0.44933595,  0.36922768, -0.98222754,
#         -0.99080146, -0.46905671, -0.85458441,  0.30371103, -0.19600759,
#          0.37074916, -0.23043892,  0.37348896, -0.27847398, -0.32185497,
#          0.34877892, -0.7672086 , -0.86766844,  1.28606393,  1.78556983,
#         -1.28411832,  0.41695718,  0.05710252,  0.96682428,  0.4015583 ,
#          0.53872108,  0.16526766,  0.2673823 , -0.19097936, -0.21956602]),
#  array([ 0.44182843,  0.02303163,  0.32667697, -0.90502704,  0.34041516,
#          0.6549559 ,  0.20715402, -1.69152574, -0.50700087, -0.68918824,
#         -0.31975085,  0.88256128,  1.07694732,  1.30402792, -0.41204528,
#          0.27228838, -0.26293891,  0.53917621, -0.29590193,  1.22301412,
#          0.69004124, -0.64671991, -0.56767369,  0.18697214, -1.98934766,
#         -0.43980032,  0.27576285,  1.99016968,  0.13463342,  0.337467  ,
#         -0.70651534, -0.12111549,  0.35595494, -0.90732063,  0.5157668 ,
#         -0.06345259, -0.80682565, -0.57189931,  0.45568662, -0.1950421 ,
#         -1.44651082, -0.19437353,  0.3694012 ,  0.86653458, -0.02433875,
#          0.12664052,  0.36511799, -0.26537218, -0.73539289, -0.74728614]),
#  array([ 7.01304125e-02, -5.94019365e-02,  8.63773694e-04, -5.94383308e-01,
#          8.04609167e-01, -3.98092236e-01,  9.25676645e-01, -1.73676740e+00,
#          3.07604537e-01,  2.25385791e-01, -5.30781020e-01,  4.56380742e-02,
#         -2.73283521e-01,  5.77470177e-01,  2.19595957e-01, -3.77177251e-01,
#         -1.05034532e+00,  2.73204186e-01, -1.03929167e+00,  8.81700792e-01,
#         -1.82833645e-01, -4.88301659e-01,  1.93995219e-02,  1.76355978e+00,
#         -1.09804933e+00, -6.11498475e-01, -1.25843617e-01,  3.35400098e-01,
#         -1.46316977e-01,  6.76088850e-01, -8.03083815e-01, -7.57689027e-01,
#          2.91355555e-01, -1.82732370e+00, -1.41733196e-01,  3.51409772e-01,
#         -1.40645381e+00, -6.05821432e-01, -4.18470472e-01,  3.86722332e-01,
#         -6.94851085e-01, -1.70200372e-01,  4.42894420e-01, -1.61328505e-01,
#          5.71167214e-01, -6.12738489e-01, -4.17502830e-01,  3.45855899e-01,
#         -1.00588396e+00,  5.55265149e-02]),
#  array([ 0.26241587,  0.1430023 ,  1.57014957, -0.99325229,  0.0776672 ,
#         -0.45624705,  0.03959832, -3.14379618,  0.69171721,  0.08420575,
#         -0.54906192,  0.28688198, -0.28628015,  1.2992593 , -0.70923636,
#          0.36893315,  0.58981874,  0.34189026, -0.64281855, -0.47887068,
#          0.21557534, -1.277775  ,  0.20156639,  0.78683472, -1.43464609,
#         -1.52559759, -0.03730139,  0.3222014 ,  1.05428755,  0.74085025,
#          0.53219783, -1.23100665,  0.23255678, -0.85236515,  0.23779256,
#          0.942779  , -0.35339382, -0.75013277,  0.40208526,  1.00397634,
#         -0.43880963,  0.12017732, -0.20215468,  1.31041679, -0.42617042,
#          0.01554223, -0.2938954 ,  0.66164786, -0.8216978 , -0.47567089]),
#  array([ 0.2165638 , -0.34672997, -0.20474344,  0.17374671,  1.01797377,
#          1.16581595, -0.0806074 , -0.84882152, -0.36774805, -1.01557724,
#          0.0355019 ,  0.6538074 ,  0.01888811,  1.27745898,  0.17884072,
#          0.52826126, -0.39356796, -0.19159745, -0.38629382, -0.5310301 ,
#          0.42982104, -0.29379553, -0.2527588 ,  0.55895501, -1.36935461,
#         -1.17504413,  0.25852382,  0.31503802, -0.04549151,  0.36677722,
#         -0.48826071, -0.15822024, -0.3109804 , -1.46322557,  0.53825427,
#          0.69949284, -0.4682495 , -0.27444485,  1.09509816,  0.47631   ,
#         -0.55236208, -0.21129345, -0.01121331,  0.40432158, -0.2156254 ,
#         -0.28933395,  0.05717282,  0.43198711, -0.22832808,  0.08104525]),
#  array([-6.05426366e-01, -2.23909386e-01, -2.60788450e-01,  2.96870039e-04,
#          9.23263680e-01,  6.38793160e-01,  2.10444946e-01, -5.51264131e-01,
#         -6.60054588e-02, -1.30683498e+00,  7.18793813e-02,  1.95815348e-01,
#         -3.43657322e-01,  1.47229703e+00,  7.20226221e-01,  3.92924283e-01,
#         -1.04436029e+00, -1.86314605e-01, -4.16213142e-02, -1.41971678e-01,
#         -1.40344846e-01, -1.22209698e+00, -2.58243387e-02,  6.25408707e-01,
#         -2.01825601e+00, -3.42991945e-01,  1.33204256e-01, -1.35599550e-02,
#          7.38175237e-01,  4.93751521e-01, -8.59540631e-01,  3.52057398e-01,
#          2.22385413e-01, -1.22467723e+00,  5.00939082e-01,  1.38237461e-01,
#         -5.82156795e-01,  1.36920505e-03,  1.17826495e+00,  2.06437401e-01,
#         -3.05221329e-01, -5.39396912e-01,  3.92198753e-01, -2.04225532e-03,
#         -1.78285045e-01, -9.14280483e-01,  5.27944087e-01,  1.89278231e-01,
#         -2.19788375e-01, -2.51410687e-01]),
#  array([ 0.15900769, -0.28354428,  0.09807471, -0.35416858,  0.5500779 ,
#         -0.36848893,  0.66127132, -0.5669063 ,  0.40161227, -1.16697123,
#          0.28598485,  0.33289794, -0.402438  ,  0.68432338,  0.03369433,
#          1.15778593,  0.20258227,  0.14950486, -0.95758401, -1.29446991,
#          0.3397895 ,  0.27435727,  0.84402381,  0.6694028 , -0.92079987,
#         -0.30920874,  0.16089833,  0.01114427,  0.46276232, -0.05608774,
#          0.33067812, -0.06081085,  0.61238044, -0.03516211,  0.61695639,
#         -0.14196328,  0.06381749,  0.02021414,  0.68895728,  0.71380951,
#         -0.08008191,  0.00769708, -0.20352196,  0.01426837, -0.45124804,
#          0.19768826, -0.37945581,  0.1991703 , -0.19007168,  0.03481723]),
#  array([-8.45633509e-01, -1.16043809e-01,  7.06875342e-02, -8.43023524e-02,
#          1.00994851e+00, -7.42191360e-01,  7.59045376e-01, -5.14332063e-02,
#          1.24124954e+00, -1.18963163e+00,  7.07882609e-01,  6.74616886e-01,
#         -7.60315166e-01,  4.10915697e-01, -1.21684992e-01,  1.37495098e+00,
#          5.27561746e-03, -2.02699777e-01,  4.84327914e-01, -1.33442032e+00,
#          5.57272672e-01, -8.91734183e-01,  2.11328166e-01,  1.47993490e+00,
#         -1.90352171e+00, -1.63852352e+00,  7.58282444e-01, -1.12605973e+00,
#          9.84237133e-01,  5.12076345e-01, -1.12618589e+00, -3.68081581e-01,
#          4.39021964e-01, -1.01246778e+00, -1.63871884e-01,  1.46258166e+00,
#          8.85432699e-03, -1.47360691e-03,  1.76063020e+00,  3.55588968e-01,
#         -3.36378552e-01, -2.02513860e-01,  3.34377568e-01,  1.03186163e+00,
#          3.01141295e-02,  5.10815522e-02,  1.36226419e+00,  1.57741169e+00,
#         -5.51938560e-01,  2.43379020e-01]),
#  array([-0.09881654, -0.49666393, -0.84953339,  0.12445372,  1.75342656,
#         -0.21007102,  1.14291464, -0.43497064,  0.96662711, -0.85281717,
#          0.81196615, -0.10751674, -0.44867652,  0.35505003,  0.42783567,
#          1.86197302, -0.18567682,  0.0514579 , -1.19985867, -0.76203737,
#          0.19219416,  0.58306886,  0.06401043,  1.22960001, -2.13849993,
#         -0.45755701,  0.078262  ,  0.13392586,  0.65624252,  0.17845493,
#          0.2521267 , -0.98852903, -0.22281621, -0.16272674,  0.38047548,
#          0.27459476,  0.20002169, -0.59393795,  1.12863122,  1.06952536,
#         -0.48632386, -0.25024501,  0.50707008, -0.10188283, -0.67778779,
#         -1.00409624,  0.64472576,  0.62339428, -0.36787661,  0.7101705 ]),
#  array([ 6.48397247e-01, -3.22362812e-01, -3.55939788e-01, -3.64072494e-01,
#          8.03108728e-01, -1.57225730e-01, -6.44023687e-02, -1.24725876e+00,
#          2.30824561e-01, -3.09859084e-01,  4.96644772e-02,  5.03022967e-01,
#          6.28856370e-01,  5.70763724e-01,  1.08494447e+00,  5.33400597e-01,
#         -4.59568206e-01,  4.85407424e-01, -9.60381090e-01,  1.01609166e-01,
#         -2.99954516e-01, -6.65626197e-01, -5.39807723e-02,  6.76569098e-01,
#         -2.04248346e+00, -4.03822355e-01, -4.16416892e-03,  6.49744037e-01,
#          2.52741472e-01,  2.29971937e-02, -3.78564773e-01, -1.12186913e-01,
#          3.20537383e-01, -1.20645854e+00,  2.63062707e-01,  4.81331123e-01,
#         -2.57098932e-01, -4.44473031e-01,  3.29046838e-01,  3.04989734e-01,
#         -1.47791809e-03, -4.60945968e-01,  1.00057264e+00, -3.50663786e-01,
#          2.62577806e-01, -6.86065002e-01, -1.59522628e-01, -2.26358362e-02,
#         -8.88057100e-01, -4.07316049e-01]),
#  array([ 0.5926984 , -0.10377498, -0.01618299, -0.6267782 ,  1.34306367,
#          0.39210577,  0.1246009 ,  0.0544522 ,  0.12011064, -0.52022813,
#          0.62334281,  0.683353  ,  0.4111707 ,  1.089912  ,  0.37047049,
#          0.88789147, -0.58357185,  0.07439869, -0.6263576 , -0.45741749,
#          0.47144803,  0.0346595 ,  0.24477658,  0.10570561, -0.87103761,
#         -0.30051818,  0.25330436,  0.07849666,  0.43992447, -0.16549842,
#         -0.36693428, -0.32857364,  0.4499834 , -1.71495201,  0.10599479,
#          0.48212466, -0.71445841,  0.44867102,  0.54072954, -0.46041978,
#          0.4374738 , -0.16055124, -0.27405945, -0.16210532, -0.37700459,
#         -0.23557946,  0.33549946,  0.04852733, -0.66907931, -0.44118639]),
#  array([ 0.08278515, -0.61417672, -0.08982925, -0.38581177,  1.53765417,
#          0.25298771,  0.33727122, -0.2617494 ,  0.19952349, -0.48236204,
#          1.83957232,  0.57262038, -0.98571377,  1.1730891 ,  0.23468354,
#          2.34183761, -0.3614553 , -0.46455348, -0.61274651, -2.22909485,
#          1.50394016, -0.21540247, -0.32281372,  1.59473674, -2.49310728,
#         -2.03258055,  0.62115609, -0.39420047,  0.77887182,  0.01040886,
#          0.1046345 , -1.18903986,  0.34950726, -1.20057881,  0.36505147,
#          0.99446187,  0.12317555,  0.04041544,  2.18945381,  1.36466307,
#          0.13067664, -0.28128311,  0.91788956,  0.69048292, -0.51682126,
#         -0.22112576,  0.85360522,  0.89298797, -0.81133895,  0.68332844]),
#  array([ 0.70737099, -0.54718668,  0.49556006, -1.01124523,  0.75194485,
#         -0.55973757,  0.87442321, -1.96298417,  0.68022986, -0.72365939,
#          0.37439455,  0.31549579, -0.38226692,  0.30775752,  0.0810695 ,
#          1.04916905, -0.47952439, -0.38102717, -0.74545071, -1.41893576,
#          0.21189784, -0.93862314,  0.77866283,  1.31002056, -1.72533275,
#         -0.69092995, -0.0127942 , -0.74005949,  0.97223738,  0.36830921,
#          0.85251966, -0.156525  ,  1.55345603, -0.76884217,  0.07868149,
#          0.82069114,  0.23163164,  0.03546994,  0.71555116,  1.11514822,
#         -0.22744696,  0.00716082,  0.7824564 ,  0.57021622, -0.44407525,
#         -0.11543187,  0.6818196 ,  0.48598937, -0.11591438,  0.68007533]),
#  array([ 0.230263  , -0.48918693,  1.25731393, -0.74826214,  0.87920675,
#          0.11562256,  0.09638855, -1.75483045,  1.30604926, -0.33810906,
#         -0.92028309,  1.68499641, -1.32462246,  1.63711894, -1.17022351,
#          1.61188379,  0.35908797, -0.33075333, -0.00765169, -2.6571484 ,
#         -0.16714162, -1.77773727,  0.71909658,  1.53378599, -1.58512237,
#         -3.30547772, -0.25279997, -0.77325578,  1.74219259,  0.53077171,
#          0.56948672, -1.63658093,  0.3269594 , -1.77697777, -0.207517  ,
#          1.49581075, -0.32075091, -0.17633232,  1.56413856,  0.84900932,
#          1.27275595, -0.11059341, -0.20459638,  1.41117931, -0.0756613 ,
#         -0.17187639,  0.59328847,  1.48380652, -0.82977899,  0.49852521]),
#  array([-0.5544732 , -0.1980668 ,  0.06254487, -0.64668692,  0.1492834 ,
#          0.17718048,  1.07025339, -0.33020546,  0.13536748, -0.65607242,
#         -0.57573508, -0.11387959, -0.13769251,  0.95572014, -0.76706701,
#          0.28260292,  0.0191341 ,  0.4716696 ,  0.04738777, -0.97146499,
#          1.00741217, -0.1919406 , -0.59253973,  0.85167481, -1.27566538,
#         -0.56981614, -0.26184935, -0.49418926,  1.52334986, -0.14473914,
#         -0.7496208 ,  0.25826003,  0.32572457, -1.84423736, -1.15941994,
#          0.31348731, -0.19080707,  0.29673073,  0.53541791, -0.69010107,
#         -0.2596101 , -0.52022157, -1.01221763, -1.04584743,  0.38229578,
#          0.86284154,  0.42743849, -0.1956231 , -0.02157986, -0.99983116]),
#  array([ 0.43953277, -0.12607949, -0.07865468,  0.05578125,  0.23313704,
#         -0.64371093,  0.43058171, -0.40081717, -0.10182714,  0.22807053,
#         -0.93284524,  0.37335252, -1.72854869,  0.06048086, -1.05997557,
#          1.46522206, -0.19617484, -0.40823257, -1.6815595 , -1.39603434,
#         -0.07427021,  0.04927836,  0.0395602 ,  1.16629221, -0.43925396,
#         -1.78573067, -1.59741377,  0.0270203 ,  0.97582567,  0.19155127,
#         -0.15539428, -1.47204494,  0.41211293, -1.02622604, -1.18051023,
#          0.91364797, -1.20239101, -0.181206  ,  1.67295218,  0.94838431,
#         -1.26915907,  0.15065373, -1.04515704,  0.48386047,  0.51750964,
#          1.05812851, -0.60426982,  0.41705594, -0.43948132, -0.18779015]),
#  array([-0.5803378 , -0.12826456,  0.1569744 , -0.80139609,  1.18186728,
#          1.02549175,  0.38131258, -1.81677395,  0.86171826, -1.28639772,
#          0.25150918,  0.13833989,  0.06542352,  0.3028516 ,  0.2641577 ,
#          0.33881169, -0.37896876,  0.50165197,  0.47538997, -0.14872145,
#          0.56460343, -0.53762719, -0.27512387,  0.83276069, -2.31796159,
#         -0.14587223,  0.65448272, -0.23170915,  2.18107749,  0.35385588,
#         -0.68815718, -0.07701044,  0.04100481, -0.53369481, -0.24971501,
#          0.25289197, -0.10001124, -0.01644666,  0.4395322 , -0.14915174,
#         -0.17492492, -0.1376363 , -0.32610543, -0.73227911, -0.16097183,
#         -0.3208395 ,  0.22547049,  1.21845975, -0.83724962, -0.53755582]),
#  array([ 0.88334901, -0.55395587,  0.47847975, -0.83715673,  0.65348193,
#         -0.2352761 ,  0.07090598, -1.73081098, -0.11691619, -0.52677209,
#          0.12008852,  0.24304956, -0.28430088,  0.76605155,  0.25395555,
#          0.28436341, -0.86474709,  0.73066642, -1.10091925, -0.20479637,
#          0.18466452, -0.57409296,  0.13553739,  0.64344711, -1.76902696,
#          0.51113255,  0.02816233,  0.33925985,  0.62697972, -0.20043108,
#         -0.23240379,  0.2866345 ,  0.63577217, -1.75678264, -0.22953474,
#          0.5317387 , -0.12984564, -0.36863074,  0.4212556 ,  0.50524992,
#         -0.59677456, -0.05209831,  0.12991913,  0.06838552,  0.2139317 ,
#         -0.52396503, -0.1296359 , -0.48834381, -0.42930731, -0.56993156]),
#  array([ 0.7498317 , -0.36229175,  0.11533122,  0.74750888,  0.06454009,
#         -0.15780553,  0.29966001, -0.60079604,  0.37780451, -1.03019959,
#         -0.7676384 ,  0.14480135, -0.35261316,  0.04670898, -0.2560931 ,
#          0.56817828, -0.77245673,  0.248845  , -0.67337045, -1.076211  ,
#          0.4061084 ,  0.12780341,  0.51941058,  1.46173975, -0.98097697,
#         -0.72327394, -0.78394674, -0.26058795,  0.85744401, -0.42875108,
#         -0.55887479,  0.67953295,  0.06016656, -0.16893674,  0.16606794,
#          0.44936165, -0.64186881, -0.22265712,  0.46312158,  0.46325463,
#         -0.67318912,  0.04718762, -0.71436613, -0.27767015, -0.88167841,
#          0.09975541, -0.50612362,  0.70370113, -0.64963287, -0.21987616]),
#  array([ 0.24080119, -0.80486431,  1.3298569 , -0.67931493,  0.78407487,
#         -0.0101792 ,  0.57059566, -2.05488284,  1.14780066, -0.25345788,
#         -0.38214152,  0.12116945, -0.53258578,  1.61438725, -0.54902427,
#          0.76369022, -0.32218002,  0.17246196, -1.27871961, -1.95160185,
#          0.46002833, -0.83664948,  0.57304903,  1.04705953, -1.55013478,
#         -1.6271899 , -0.54893066, -0.54777439,  1.37751997,  0.76011365,
#          0.68140553, -1.24222267,  0.29258539, -0.72913174, -0.7928024 ,
#          0.91591653, -0.07849371, -0.75737859,  0.62982784,  0.96699229,
#         -0.18053535,  0.34985268, -0.68285408,  0.85976473,  0.1989091 ,
#          0.33175059,  0.27227666,  0.87546554, -1.10936169, -0.39472047]),
#  array([-0.78952117, -0.58270857,  0.74735249, -0.46512425,  1.2280252 ,
#          0.37498717,  0.40394849, -0.728254  ,  1.13674612, -1.34898726,
#          0.08207415,  0.99686396,  0.38933407,  1.47753147,  0.04951326,
#         -0.24160875,  0.66241699, -0.18741386,  0.82816451, -1.96335837,
#          1.25805556, -1.15936035,  0.15069618,  1.92042757, -2.63564031,
#         -1.68665962,  0.17672719, -0.96107009,  2.46584414,  0.63488336,
#         -1.33953078, -1.08109254,  0.54918917, -1.07929588, -0.61078007,
#          1.94886588,  0.52696312, -1.14052948,  1.08544295, -0.6903041 ,
#          0.74951515, -0.51518065,  0.17235131,  0.37292499, -0.15125296,
#          0.14716207,  0.86525469,  1.70862569, -1.43294127,  0.24545948]),
#  array([-3.11369668e-01, -5.36687960e-01,  1.12395604e+00, -9.19090410e-01,
#          3.41032672e-01,  2.45541023e-01, -8.42454666e-03,  5.19852665e-01,
#          1.89946186e-01,  2.42750841e-01, -2.15624117e-01,  1.09837319e+00,
#         -1.06032272e+00,  1.32103553e-01, -7.40924209e-01, -2.31952644e-01,
#         -8.60205924e-01,  4.04241192e-01, -5.60425318e-01, -9.82628098e-01,
#         -6.46327151e-01, -1.09179781e+00, -4.67184660e-01,  5.75529268e-01,
#          4.86084398e-02, -1.14655809e-01, -5.63706774e-01,  1.55054337e-01,
#         -7.79924627e-02,  1.89472707e-01, -6.65296775e-01,  1.56722738e-01,
#          4.87612361e-01, -3.26328505e-01, -1.76377682e+00,  1.75878801e-01,
#         -9.26654204e-01, -1.44137763e-03,  5.69402190e-01,  1.04406621e-02,
#         -3.40682692e-01, -4.97330724e-01, -3.61260588e-01, -1.75904433e-01,
#          5.76204957e-02,  8.32694906e-01,  1.35383159e-01, -6.15021029e-01,
#         -1.31437528e-01, -1.92768739e-01]),
#  array([-0.08108309, -0.37872129, -0.38629897, -1.15596245,  0.23870729,
#         -0.02110929, -0.32579606, -1.91513763,  0.64040211, -0.44986937,
#          0.11635948,  0.14886933, -0.27873   ,  1.47595392,  0.36046192,
#          0.8963179 , -0.82613553,  0.12923765, -0.85800532, -0.53616334,
#         -0.31190237, -1.30879231,  0.50071128,  0.4440926 , -2.42851052,
#         -0.4195787 ,  0.01843987,  0.68928696,  0.13286385,  0.30951947,
#          0.00901519,  0.60622396,  0.17707897, -1.04466679,  0.03062071,
#          0.64511836,  0.06724431,  0.4117532 ,  0.60828214,  0.48554336,
#          0.29445326, -0.37172889,  0.8340686 ,  0.57251527, -0.07485913,
#         -0.35239757,  0.56481338, -0.04231755, -1.06653595, -0.22108757]),
#  array([ 0.01993406, -0.34625098, -0.06493517, -0.62203846,  0.68000413,
#          0.07575011,  0.24629172, -1.31920539,  0.757317  , -0.60385494,
#          0.18797415,  0.45355472, -0.54259411,  0.80032928,  0.30963642,
#          0.97060436, -0.46499486,  0.17008342, -1.09692635, -1.50807193,
#          0.09496549, -0.60843908,  0.47007188,  0.99429778, -1.66445995,
#         -0.92952642, -0.24448385,  0.01370386,  0.27735941,  0.14407384,
#          0.06954106, -0.02117139,  0.34988223, -1.17092412,  0.05948191,
#          0.81294818, -0.12226234,  0.06603158,  1.01912356,  0.95582288,
#          0.03936941, -0.32686525,  0.31675741,  0.62764539,  0.16974099,
#          0.08070121,  0.09826982,  0.35580553, -0.41265131,  0.11964597]),
#  array([-0.49787976,  0.04981738,  0.57213319,  0.0377373 ,  1.016724  ,
#         -0.47136784,  0.45048621, -0.66487632,  0.77847319, -0.6751297 ,
#          0.21266186,  0.41329338, -0.66597207,  0.12302732, -0.09697372,
#          1.55166277, -0.17239185,  0.15068176, -1.11443323, -1.32427076,
#         -0.06806634, -0.54172936,  0.20821875,  0.80478191, -1.10790068,
#         -1.43618693, -0.68500915, -0.06564135,  0.18936213,  0.19215268,
#          0.17165537, -0.65229301,  0.11347271, -1.25789547, -0.0730828 ,
#          1.22175571, -0.27081989,  0.62333096,  1.80441663,  1.04650985,
#         -0.21246579,  0.15370066,  0.4476768 ,  0.37894808, -0.28226518,
#          0.44310192,  0.71488972,  0.46827245, -0.80445473,  0.3580042 ]),
#  array([-0.08864502, -0.2101409 , -0.43452518, -1.00958655,  0.25184194,
#         -0.09946771, -0.33326065, -1.83938852,  0.60936883, -0.50630307,
#          0.21222895,  0.33840279, -0.26321585,  1.58750064,  0.52218392,
#          0.83112998, -0.69241223,  0.01058898, -0.89966827, -0.7402331 ,
#         -0.40355409, -1.36566109,  0.62123314,  0.5927502 , -2.24405746,
#         -0.41855974,  0.01691675,  0.62746246,  0.18089526,  0.35120361,
#         -0.00232579,  0.42650899,  0.20904228, -1.01524267, -0.01011465,
#          0.65945075,  0.01449112,  0.52537403,  0.6295749 ,  0.52302829,
#          0.44550092, -0.30685459,  0.73763686,  0.50612744,  0.03055374,
#         -0.48225564,  0.45973779,  0.05582303, -1.21760896, -0.35288097]),
#  array([ 0.49841582, -1.05831427, -0.75583393, -0.63973727,  2.16500474,
#         -0.03345407,  0.53438202, -0.77143702,  0.56841807, -0.74409075,
#          1.50075404,  0.2379371 , -0.84304104,  1.58519507, -0.00308018,
#          2.64861627, -0.57543756,  0.07182177, -1.92975329, -1.2858604 ,
#          0.9295391 , -0.06108894, -0.11799555,  0.78642244, -2.10707693,
#         -1.15892975, -0.42902659, -0.45797858,  0.53449366,  0.28902113,
#          0.65963425, -1.49315429,  0.00366013, -0.66995347,  0.96317304,
#          0.67794806,  0.1842414 , -0.33712815,  2.44118969,  1.42321963,
#          0.05759163, -0.7935214 ,  0.60959519,  0.69898744, -0.39717183,
#         -0.9863466 ,  0.97631701,  1.90405413, -0.40208877,  0.85679393]),
#  array([-0.05783487, -0.99946982, -0.05595876,  0.09428365,  0.91764388,
#         -0.21158303,  0.10580256, -1.01697856,  0.15288524, -1.09769167,
#         -0.03900206,  0.57091621, -0.64442992,  0.49512308, -0.54367711,
#          2.19147085, -0.23938951,  0.26736927, -2.4791929 , -1.12840983,
#          0.65528092, -0.51630153,  0.75691816,  0.43560656, -2.48416736,
#         -1.42290385, -0.69967363, -0.1896471 , -0.23013088,  0.2943789 ,
#          0.09036425, -1.47881717,  1.14457823, -0.38214312,  0.2823725 ,
#          0.82063775,  0.13444327, -1.05163992,  0.96064708,  1.39602949,
# ...
#          0.44092193,  0.76309778, -0.20043011, -0.2574101 , -0.57430333,
#          0.88769322, -0.9162171 ,  0.4676472 , -0.70335517,  0.33889623,
#          0.76053896,  0.70642663, -0.02542645,  1.00079178, -1.1590473 ,
#         -0.28737108, -0.64561722,  0.58764456, -0.20587621, -0.79410558,
#         -0.5409785 , -0.18776553,  0.30986705,  0.27202342,  0.2265958 ,
#         -0.32751413, -0.74223352, -1.74116943, -0.19730381, -0.57272305,
#         -1.531873  ,  0.20151264, -0.65917448, -0.02497799,  1.02981902,
#         -0.93812755,  0.29629522,  1.22861688, -0.29407585, -0.18349677]),
#  array([-0.12271232, -0.58617455, -0.59247822,  0.48514458,  0.23791547,
#         -0.04795308, -0.30427481,  0.24198648,  0.71751607, -0.6746688 ,
#          0.33340738,  0.71260669, -0.1792942 , -0.59953849,  0.9610095 ,
#         -0.50241914, -0.70990233,  0.40803623, -0.26710263,  0.09000004,
#          0.02291714, -0.02394502, -0.05984384,  0.9041015 , -1.0702085 ,
#         -0.10204941, -1.632527  ,  0.69682421, -0.074506  , -0.90015459,
#          0.10684876, -0.64358289,  0.07278805, -0.94316428,  0.16484954,
#          0.5299741 , -0.51767227, -0.75174079,  0.94387293, -0.38338536,
#         -0.00549192,  0.06383097, -0.41313292, -0.58538473,  0.08765718,
#         -0.07586008,  0.32652437,  0.6850959 , -0.24237705,  0.10341825]),
#  array([-0.01609016,  0.19052693,  0.19008556, -0.67104538,  0.28153934,
#         -0.85632959,  0.86054235, -1.19854491,  0.49375752, -0.66704399,
#         -0.09244709,  0.36415835, -0.17130554,  0.1582378 , -0.15970378,
#          0.17264914, -1.093488  ,  0.39754327, -0.80647658, -0.96514812,
#         -0.32175324,  0.10562314, -0.08712651,  1.04220966, -1.36555744,
#          0.65604348, -0.03275424,  0.04353025,  0.73099168, -0.69320748,
#         -0.2606085 ,  0.4059053 ,  0.19576162, -0.59924733,  0.13647088,
#          0.27561765,  0.01060891, -0.62534894,  0.3248249 ,  0.71778377,
#         -0.92694608,  0.15823   , -0.31969349, -0.29911787,  0.3140008 ,
#         -0.47716792, -0.31850449, -0.31466728, -0.52402117, -0.45843737]),
#  array([ 0.59390676, -0.26955644, -0.11237522, -0.65395929,  0.6293195 ,
#         -0.31661348,  0.41982501, -0.89063308,  0.44466266, -0.70879742,
#          0.26337639,  0.41224726, -0.08239059,  0.7127026 ,  0.13063598,
#          0.4516296 , -1.28697053,  0.52507669, -0.85769616, -0.42319678,
#          0.27915649,  0.43702704,  0.47033751,  0.18967391, -1.53527333,
#          1.14238346, -0.3741663 ,  0.3176064 , -0.3839969 , -1.05400455,
#          0.17750663,  1.04872406,  1.09001643, -0.60106906,  0.49911158,
#         -0.16844083,  0.42717172, -0.83138163, -0.55106832,  0.55435762,
#         -1.0919563 , -0.08729657, -0.57125341,  0.2786003 ,  0.28610992,
#         -0.38713211, -0.64002711, -0.41669955, -0.11709592, -0.36494207]),
#  array([-0.25611097, -0.16884806,  0.23081173, -0.08042326,  0.9505339 ,
#          0.83715285,  0.55266316, -0.84120315,  0.63677811, -0.93408887,
#         -0.08642301, -0.22037873,  0.65832162,  0.95937418,  0.21435464,
#          0.0296587 , -0.0669393 ,  0.49418532,  0.78180606,  0.43203321,
#          0.9810494 ,  0.1023304 , -0.42094504,  0.76851828, -2.19184525,
#          0.81211945,  0.00296521,  0.89257253,  0.94547741,  0.84470788,
#         -0.17931685, -0.25371261,  0.28876836, -0.87455452,  0.20190355,
#         -0.02017621,  0.14322097, -0.54682007, -0.09950281, -0.45578911,
#         -0.90147282, -0.05295208,  0.05061751, -0.64223841,  0.72047938,
#         -0.13974862,  0.04035874,  0.4794683 , -0.40937394, -0.75790332]),
#  array([-0.63667163, -0.3198017 ,  0.56843201, -1.20624266,  0.55219991,
#          0.36100627, -0.09869525, -2.30130843,  0.41914988, -0.41615492,
#         -0.44216453, -0.52542086, -0.26914191, -0.00485758, -0.30723836,
#         -0.11082536, -0.40976169,  0.51457252, -0.42838168,  0.53013613,
#          0.44620303, -0.00382791, -0.31218163,  0.83749006, -2.52363189,
#          1.67012136,  0.01095913,  0.80193198,  1.47014611,  0.63725926,
#         -0.53465639, -0.39515848, -0.24592455, -0.59614444, -1.34097259,
#          0.42826303,  0.40662566, -0.26037152, -0.70231251, -0.76147407,
#         -0.5793037 , -0.84166788,  0.69745635, -1.11816711, -0.42478082,
#         -0.60349473,  0.02772497, -0.72079211, -0.77797063, -0.02018863]),
#  array([-0.51749674, -0.88496162,  0.93001573, -0.05243577,  0.29336064,
#         -0.28577633,  1.30986545, -1.11331638, -0.84506981, -0.91504712,
#          0.27654753,  0.81213137,  0.24887794, -0.00820245,  0.40035801,
#          0.21922646, -0.36212256,  0.70151166, -2.16146881,  1.52872174,
#         -0.05843449, -0.48126221, -0.1477586 ,  0.28503271, -0.96499242,
#          0.1352316 ,  0.73587399,  0.97684043, -0.8572843 ,  1.1821467 ,
#         -1.24463616, -1.04467421,  0.26059939,  0.08511659, -0.47039496,
#          0.78115114, -0.4334058 , -1.49803918, -0.31767027,  0.19299905,
#         -1.32452894, -0.22223216,  0.85302746, -0.33350728, -0.15482611,
#         -1.36962145,  1.49588416, -0.3907192 , -1.08486274,  0.70586291]),
#  array([ 0.134469  , -0.13274328,  0.19416418, -0.24267882,  0.18676115,
#         -0.50717104,  0.56294028, -0.34579393,  0.01717277, -0.91050659,
#          0.19275499,  0.26739073,  0.22860466,  0.38461544,  0.30163978,
#          0.2523265 , -1.34986608,  0.65144475, -0.9567958 ,  0.05266365,
#          0.2176595 ,  0.56114851,  0.09474014,  1.10319341, -1.14410053,
#          0.77497194, -0.14148149,  0.26524435, -0.0695827 , -0.03134998,
#         -0.13810598,  0.71944535,  0.5041157 , -0.63112965,  0.03609512,
#          0.06931866, -0.17272548, -1.20254145, -0.5398906 , -0.21633053,
#         -1.21207454, -0.0648786 , -0.72572756, -0.71401524,  0.6032392 ,
#         -0.54501254,  0.0429558 , -0.16080179, -0.09866682, -0.3559296 ]),
#  array([ 0.30371663, -0.40249131, -0.21162762, -0.0861119 ,  0.91415286,
#         -0.78046406,  0.30142064, -0.02683807,  0.16072368, -1.21237139,
#         -0.09031058,  0.70372675,  0.11021175,  0.2788867 , -0.19056627,
#          0.76358995, -1.1251622 ,  0.34738792, -1.63490222, -0.39140355,
#         -0.22421415,  0.00865595,  0.5028581 ,  0.71169982, -1.07329625,
#         -0.19282501, -0.13754377, -0.42928419, -0.2190944 , -0.19864213,
#         -0.21636014, -0.01735276,  0.48744774,  0.13163313,  0.15838594,
#          0.2556339 , -0.23569447, -1.17589034,  0.04556137,  0.50930463,
#         -0.92183064, -0.20547155, -0.49042043, -0.89991249, -0.30763642,
#         -0.19323553,  0.11935577,  0.3720948 ,  0.15246523, -0.31280788]),
#  array([-0.21053531, -0.43155284,  1.45826705,  0.11183527,  0.02234893,
#         -1.85391231,  0.54312876, -1.24263899,  0.32882407, -0.36457867,
#          0.1169725 ,  0.08914334,  0.48704816,  1.0392549 ,  0.58323918,
#          0.85445275, -1.74356443,  0.60678108, -0.82309511, -0.87212257,
#          0.51600302,  0.15299572,  0.18230663,  0.99275863, -2.08450568,
#          1.21033747, -0.33686437,  0.74232917,  0.83243758,  0.17767813,
#          1.02211169,  0.36872201,  1.30959267, -0.51114097,  0.40093911,
#          0.08541239, -0.06430321, -1.32008715, -0.61290245,  0.22347177,
#         -0.74993429,  0.50727321, -0.6451896 , -0.65716376,  0.71200055,
#         -0.57312627, -0.07941893, -0.43575206, -1.16679928, -0.67949297]),
#  array([ 0.59350116, -0.79402728, -0.19921627, -0.08964366,  0.7052586 ,
#         -1.14158885,  1.08117905, -0.93066494, -0.08365636, -0.33790745,
#          0.43098051,  0.46366104,  0.64709323,  0.21335022,  0.21439348,
#          1.22252568, -0.96386009,  0.41281355, -1.61382698, -0.74941081,
#          0.14494718,  0.00267437, -0.25617431,  0.89029691, -1.73806064,
#         -0.21640307,  0.11037698, -0.26267677,  0.13004129, -0.24813561,
#          0.57635339, -0.47276884,  1.25178089, -0.46051235, -0.09362458,
#          0.09547439,  0.36762273, -1.17789693, -0.35128798,  0.8688068 ,
#         -1.16862757,  0.16427155,  0.98685762, -0.93530968,  0.28852682,
#         -0.45518445,  0.13827773,  0.08376283, -0.845612  ,  0.26556877]),
#  array([-0.63488955, -0.4814843 ,  0.32823534,  0.18758053,  0.49346837,
#         -0.74704761, -0.45857457,  0.56630717, -0.04712379, -0.02893745,
#          1.54908047, -0.80188072,  1.46659958,  1.23099783,  1.10106888,
#          0.11756853, -2.23246951,  0.22502838,  0.20833307, -0.17866954,
#          0.80748683,  0.7512237 ,  0.18692105,  1.17150626, -2.45979293,
#          1.56983038, -1.12560525,  1.19510486,  0.35214891,  1.35304316,
#          0.80575068, -0.05457749,  1.45540445, -0.38369386,  0.52249146,
#         -0.34437024,  0.12041501, -1.9116103 , -2.14662087, -1.40126681,
#         -0.11187933, -0.31016162, -0.67070647, -2.00199145,  1.78848286,
#         -1.03090786, -0.29714523, -0.7865483 , -1.0474285 ,  0.05450216]),
#  array([ 1.29721955,  2.08886142,  0.05680899, -0.82204912,  0.67414526,
#         -2.26768   , -1.10911888, -2.04607103, -0.34744813, -0.16894224,
#         -0.02390828, -0.22084292, -0.56150483,  0.09754437, -0.49563855,
#          0.47828589,  0.20803512,  1.43049113,  0.08565773, -0.20632064,
#         -0.42158974,  1.14825936,  0.48979834,  1.48184592, -0.53189778,
#          0.4669792 , -1.09736329, -0.4213589 , -0.36154947, -0.20810336,
#          1.22373673,  0.78045961,  0.9892623 , -0.76689845, -0.69956585,
#          1.65196301, -0.84574802, -1.44558502, -0.31096206, -1.70841972,
#         -2.23437234,  0.70281167, -0.79622119, -1.10147634,  1.36995559,
#          0.34378576, -0.42559371, -1.84421699,  0.79886283,  0.19090016]),
#  array([ 0.3604057 ,  0.58737646,  0.73073496,  0.2624982 , -0.11724182,
#         -1.91271502,  0.97369364, -0.17320279, -0.28128697, -0.76055381,
#         -1.21534357,  0.16234962, -0.07886317,  0.42461494, -0.82462619,
#          0.67562767, -0.2115516 ,  0.34500165, -1.24594725, -1.42332809,
#         -0.78320102,  1.02048207,  0.88364869,  1.00694755, -0.29139569,
#          0.51451947, -0.77107618,  0.22012666, -1.2375131 , -1.11447394,
#         -0.39240513,  0.82250661,  0.05915892,  0.46432785, -0.27651001,
#          0.09079982, -0.09575322, -0.42536911,  0.93465333, -0.08866998,
#         -1.7683198 , -0.23448938, -0.65124868, -0.23663349,  0.11578033,
#          0.61440079, -0.84405339, -0.21760434,  0.81377833, -0.6252345 ]),
#  array([ 0.42416196,  1.65664955,  0.55923331, -0.7885346 ,  0.48712567,
#         -1.50871422, -0.54518114, -1.25583338, -0.07973226, -0.64746313,
#         -0.02439588, -0.17073566,  0.33204798,  0.31744838,  0.05398646,
#         -0.4518031 , -0.15346554,  1.72594777,  0.54473951,  0.37285794,
#         -0.01164883,  0.59580489,  0.79064466,  0.63397991, -0.75191241,
#          0.45813879, -0.66684554,  0.34229378, -0.25053639, -0.19842284,
#          0.73988394,  1.32746432,  0.22274305, -0.75710788, -0.02816769,
#          1.17581891, -0.2394856 , -0.99235978, -0.04881369, -1.38148427,
#         -1.91180017,  0.71086935, -0.50017813, -0.78369579,  1.0659954 ,
#         -0.06928724, -1.00516251, -1.24562627, -0.09888898, -0.30246988]),
#  array([ 0.52075466,  0.1221392 , -0.46216491, -0.65606415,  0.75361289,
#         -1.06109367, -0.23364906, -0.72926768, -0.67945442, -1.10377578,
#          0.93740743, -0.35236474, -0.44446408, -0.89854105,  0.03302239,
#         -0.05000908, -0.4096431 ,  1.74755003, -0.16164518,  0.74628143,
#         -0.66017124,  0.19628678,  0.10290242,  0.4411346 , -0.4065209 ,
#          0.03873283, -0.39882533,  0.59482075, -1.01986591,  0.28998964,
#          0.20938118,  0.04046825,  0.28962907, -1.12590507, -0.55783555,
#          0.38991218, -0.46540608, -1.20800677, -0.02774729, -1.35324548,
#         -1.18336998,  0.22495009, -0.50322751, -0.56428321,  0.73526351,
#         -0.53157854, -0.00827902, -1.01802669, -0.40171703, -0.38461799]),
#  array([ 1.01059524,  1.81601222,  0.57628712, -1.26241509,  0.78498355,
#         -1.87082649, -0.50187286, -2.09803114, -0.36603897, -0.05874515,
#         -0.45964425, -0.20309447, -0.33983919,  0.39511032, -0.57121846,
#         -0.02446419, -0.07469117,  1.04299102, -0.3095517 , -0.12254056,
#         -0.42925184,  1.00240216,  0.74824582,  1.24103285, -0.67756397,
#          1.12829782, -0.7900416 , -0.35981505, -0.13655264,  0.03920917,
#          0.85564013,  1.30132976,  0.86459199, -0.91868151, -0.23290939,
#          1.3241345 , -0.46960882, -0.98838639, -0.2790971 , -1.11832498,
#         -1.93053686,  0.48408184, -0.16035442, -0.51392859,  0.98127111,
#          0.24340246, -0.78185488, -1.81533129,  0.73034305, -0.04574541]),
#  array([ 0.83896385,  1.46571699,  0.10122963, -1.16581336,  0.31246675,
#         -1.08244206, -0.36327196, -1.49670497, -0.21366977, -0.6339401 ,
#          0.2135485 ,  0.32723084,  1.05308704,  0.23844829,  0.36324404,
#         -0.02346695, -0.40698012,  1.62733935,  0.24084713,  0.22472061,
#          0.18316668,  0.31614592, -0.1060973 ,  1.30010803, -1.56203719,
#          0.74770045, -0.26596325, -0.24374703,  0.28353984,  0.50939068,
#         -0.14016593,  1.15350992,  0.57731642, -0.76676403, -0.02355206,
#          1.09025187,  0.11920993, -0.97787394, -0.26872892, -1.4807603 ,
#         -1.50872539,  0.25139575, -0.0583442 , -0.51488889,  1.1846307 ,
#         -0.50405771, -0.91582101, -0.71221166, -0.57106263, -0.21810295]),
#  array([ 0.40082461,  0.72820101,  0.21999184, -0.26175702, -0.00350104,
#         -1.10499863,  0.50554617, -1.25261832,  0.26661161, -0.72246127,
#         -0.31084755,  0.48763227, -0.48724264,  0.23856791, -0.94497503,
#         -0.00396501, -0.731959  ,  0.58094803, -1.04806048, -0.00566746,
#         -0.50571929,  0.76693463,  1.27623585,  1.01787353, -0.75869265,
#          0.25615312, -0.49125666,  0.26389278, -0.93778371, -0.09072617,
#         -1.12392252,  1.04000919,  0.95601965,  0.74934207,  0.02305774,
#         -0.57241555, -0.18625579, -0.14219437, -0.31977393,  0.79442694,
#         -2.05174139, -0.42605655,  0.17183392,  0.07030362,  0.14070847,
#          0.1029608 , -0.21473474, -0.85895467,  0.11191672, -1.03828448]),
#  array([-0.02249613,  0.56949869,  0.42593831, -1.60543624,  0.56693544,
#         -0.88952936, -0.31103131, -1.62664333,  0.07069332,  0.06347669,
#         -0.45604022,  0.21008776,  0.68447823,  1.18351941, -0.19727308,
#          0.35152601, -0.99850455,  1.48083656, -0.15577602,  0.21168082,
#          0.38849898,  0.79883984,  0.19941383, -0.41351695, -0.74790203,
#          1.26120994, -0.74799199,  0.47525759,  0.89939092, -0.31938744,
#          0.09360666,  1.28688365, -0.00874607, -1.2377087 , -0.7259344 ,
#          0.60619557,  0.51320774, -0.88203162,  0.0269858 , -0.82558929,
#         -0.7726942 ,  1.12644135,  0.60474069, -0.24937479,  1.15586436,
#         -0.10999693, -0.13939838, -1.0989167 , -1.30088532, -1.04268408]),
#  array([ 0.09118363,  1.84903313, -0.08128407,  0.16659687,  0.37035172,
#         -1.38072242, -0.55277203,  0.31868603, -0.34335742, -0.92393666,
#          1.03224153, -0.68358412,  0.87237835, -0.65038948, -0.14735857,
#         -0.45958705, -0.11667925,  1.93162756,  1.33313579, -0.07977505,
#          0.33774974,  0.5884065 ,  0.54858916,  1.38254582, -0.96251186,
#          0.09376865, -0.92934422, -0.34283225, -0.18742305, -0.01612719,
#          1.13919503,  1.21877156,  0.04125214, -0.18863031, -0.51513989,
#          1.83914972, -0.30258222, -1.81402292,  0.21509533, -2.46542734,
#         -2.65057432,  0.58852962, -0.27802639, -1.87873708,  1.58568486,
#          0.08037508, -0.90529867, -0.82337871, -0.06984852,  1.08997276]),
#  array([ 0.1735126 ,  0.61932298,  0.619449  , -0.00412897, -0.15044697,
#         -1.87139651,  1.04651344, -1.89950518,  0.17418703, -0.78125615,
#         -1.82277507,  0.88948577, -0.01060615,  0.62282339, -1.01528694,
#         -0.17301233, -1.02836681,  0.67191071, -1.17098723, -0.64312392,
#         -1.28230601,  1.57351805,  0.93748187,  1.56846713, -0.47818699,
#          0.73385556, -0.45953543, -0.34611974, -0.94381443, -0.15644595,
#         -0.74822897,  1.60868181,  0.31263864,  0.24913018, -0.31389305,
#         -0.09318916, -1.14962993, -0.29342834,  0.23982361, -0.29823595,
#         -1.83143868, -0.18738928, -0.98930384,  0.52316943,  0.67112838,
#          0.05450043, -0.60698538,  0.09818048,  0.18961158, -0.9768075 ])]

# %%
# TF-IDF weighted Word2Vec
tfidf_feat = tf_idf_vect.get_feature_names() # tfidf words/col-names
# final_tf_idf is the sparse matrix with row= sentence, col=word and cell_val = tfidf

tfidf_sent_vectors = []; # the tfidf-w2v for each sentence/review is stored in this list
row=0;
for sent in list_of_sent[0:10000]: # for each review/sentence
    sent_vec = np.zeros(50) # as word vectors are of zero length
    weight_sum =0; # num of words with a valid vector in the sentence/review
    for word in sent: # for each word in a review/sentence
        try:
            
            vec = w2v_model.wv[word]
            
            # obtain the tf_idfidf of a word in a sentence/review
            tfidf = final_tf_idf[row, tfidf_feat.index(word)]
            
            sent_vec += (vec * tfidf)
            
            weight_sum += tfidf
        except:
            pass
    sent_vec /= weight_sum
   
    tfidf_sent_vectors.append(sent_vec)
    row += 1

# %%
pickle_out = open("WiightedTfidfW2V10kDatapoints.pickle","wb")

pickle.dump(tfidf_sent_vectors,pickle_out) #tfidf weighted w2v model



pickle_out.close()

# %%
len(tfidf_sent_vectors)
